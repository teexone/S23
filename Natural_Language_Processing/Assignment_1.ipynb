# %% [markdown]
# # Tweets Tokenization
#
# The goal of the assignment is to write a tweet tokenizer. The input of the code will be a set of tweet text and the output will be the tokens in each tweet. The assignment is made up of four tasks.
#
# The [data](https://drive.google.com/file/d/15x_wPAflvYQ2Xh38iNQGrqUIWLj5l5Nw/view?usp=share_link) contains 5 files whereby each contains 44 tweets. Each tweet is separated by a newline. For manual tokenization only one file should be used.
#
# Grading:
# - 30 points - Tokenize tweets by hand
# - 30 points - Implement 4 tokenizers
# - 20 points - Stemming and Lemmatization
# - 20 points - Explain sentencepiece (for masters only)
#
#
# Remarks:
# - Use Python 3 or greater
# - Max is 80 points for bachelors, 100 points for masters

# %% [markdown]
# ## Tokenize tweets by hand
#
# As a first task you need to tokenize 15 tweets by hand. This will allow you to understand the problem from a linguistic point of view. The guidelines for tweet tokenization are as follows:
#
# - Each smiley is a separate token
# - Each hashtag is an individual token. Each user reference is an individual token
# - If a word has spaces between them then it is converted to a single token
# - If a sentence ends with a word that legitimately has a full stop (abbreviations, for example), add a final full stop
# - All punctuations are individual tokens. This includes double-quotes and single quotes also
# - A URL is a single token
#
# Example of output
#
#     Input tweet
#     @xfranman Old age has made N A T O!
#
#     Tokenized tweet (separated by comma)
#     @xfranman , Old , age , has , made , NATO , !

# %% [markdown]
#     1. Input tweet
#     ...
#     1. Tokenized tweet
#     ...
#
#     2. Input tweet
#     ...
#     2. Tokenized tweet
#     ...

# %% [markdown]
# 1. `Moonfruit's inventive use of twitter for self-promotion. http://bit.ly/16jVaV`
#
#     `Moonfruit's, inventive , of , twitter , for , self-promotion , . , http://bit.ly/16jVaV`
#
#
#
# 2 .`Being A Work At Home Mom (WAHM) Is A 24/7 Job » Messing With My Mind http://bit.ly/17rLra`
#
#     `Being , A , Work , At , Home , Mom , ( , WAHM , ) , Is , A , 24 , / , 7 , Job , » , Messing , With , My , Mind , http://bit.ly/17rLra`
#
#
#
# 3. `@BadAstronomer Don't say I never resurrected a lost child for you: http://bit.ly/PlaitUnscrewed (I'd save that - G4's axed a lot of archive)`
#
#     `@BadAstronomer , Do, n't , say , I , never , resurrected , a , lost , child , for , you, : , http://bit.ly/PlaitUnscrewed , (, I, 'd , save , that , - , G4, 's , axed , a , lot , of , archive, )`
#
#
# 4. `Can we make sure #lovewins for babies too? Or nah... #SemST`
#
#    `Can, we , make , sure , #lovewins , for , babies , too , ? , Or , nah , ... , #SemST`
#
#
# 5. `@ArkBuilder17 we may disagree but I love ya man I don't want hard feelings #SemST`
#
#    `@ArkBuilder17 , we , may , disagree , but , I , love , ya , man , I , do , n't , want , hard , feelings , #SemST`
#
#
# 6. `The Indie Artist X Project – Awareness http://ff.im/-4V4ap`
#
#    `The , Indie , Artist , X , Project , – , Awareness , http://ff.im/-4V4ap`
#
#
# 7.  `" I just took the ""are you a true mcfly fan?"" quiz and got: yes your totally fan!!!! Try it: http://bit.ly/1pwAbT"`
#
#     `" , I , just , took , the , " , " , are , you , a , true , mcfly , fan , ? , ", " , quiz , and , got , : , yes , your , totally , fan , ! , !, ! , ! , Try , it , : , http://bit.ly/1pwAbT"`
#
#
# 8.  `Get 400 followers a day using http://www.tweeterfollow.com`
#
#    `Get , 400 , followers , a , day , using , http://www.tweeterfollow.com`
#
#
# 9.  `Fucked up on a CD-R. http://yfrog.com/9vc29j`
#
#     `Fucked , up , on , a , CD-R , . , http://yfrog.com/9vc29j`
#
#
# 10. `We chase these days down with talks of the places we will go`
#
#     `We , chase , these , days , down , with , talks , of , the , places , we , will , go`
#
#
# 11. `I truly believe that #BlackLivesMatter and that's why I'm against Planned Parenthood. #ycot #SemST`
#
#     `I , truly , believe , that , #BlackLivesMatter , and , that , 's , why , I, 'm , against , Planned , Parenthood , . , #ycot , #SemST`
#
#
# 12. `They haven't eliminated #murder. They just call it by a different #name. #prolifeyouth #prolifegen #SemST`
#
#     `They , have , n't , eliminated , #murder , . , They , just , call , it , by , a , different , #name , . , #prolifeyouth , #prolifegen , #SemST`
#
#
# 13. `@ProWomanChoice forcing women to change their body's normal function is the epitome of controlling women. #SemST`
#
#     `@ProWomanChoice , forcing , women , to , change , their , body , 's , normal , function , is , the , epitome , of , controlling , women , . , #SemST`
#
#
# 14. `@EmilyBeaulieu1 maybe that's what he wants #SemST`
#
#     `@EmilyBeaulieu1 , maybe , that's , what , he , wants , #SemST`
#
#
# 15. `I refuse to let people like you shame and insult women for accessing healthcare. Sorry. Just no.`
#
#     `I , refuse , to , let , people , like , you , shame , and , insult , women , for , accessing , healthcare , . , Sorry , . , Just , no , .`

# %% [markdown]
# ## Implement 4 tokenizers
#
# Your task is to implement the 4 different tokenizers that take a list of tweets on a topic and output tokenization for each:
#
# - White Space Tokenization
# - Sentencepiece
# - Tokenizing text using regular expressions
# - NLTK TweetTokenizer
#
# For tokenizing text using regular expressions use the rules in task 1. Combine task 1 rules into regular expression and create a tokenizer.

# %%
import re
from typing import List

# %%
def white_space_tokenizer(text: str) -> List[str]:
    return re.findall(r"\S+", text)

# %%
import sentencepiece as spm
import os

if not os.path.exists("./Assignment1_data/train.txt"):
    with open("./Assignment1_data/train.txt", "w+", encoding="utf-8") as train:
        for fname in os.listdir("./Assignment1_data/"):
            with open(os.path.join("./Assignment1_data/", fname), encoding="utf-8") as input_file:
                train.write(input_file.read())
                train.write("\n\n")
    
trainer = spm.SentencePieceTrainer.train(input="./Assignment1_data/train.txt", vocab_size=500, model_prefix="m")
model = spm.SentencePieceProcessor(model_file="m.model")

# %%
def sentencepiece_wrapper(text: str) -> List[str]:
    return model.encode(text, out_type=str)

# %%
FRAG_PATTERN = r"(?=\w)(?<!ca)(n't)|('d)|('s)|('ll)|('ve)|('re)"
LINK_PATTERN = r"(\w+:\/\/[\w\.\#\?\/]+)"
WORD_PATTERN = r"(\w(?:\s\w)+)\s?|(\w+(?=n't))|(\w+)"
ALIAS_PATTERN = r"((?:@|#)?\w+)"
PUNCTUATION_PATTERN = r"([\?\.!:\-;,\)\(\]\[\}\{]{1}|\*\&\%)|(\"|\')"
SMILEY_PATTERN = r"(?=[\w'\&\-\.\/\(\)=:;]+)|((?::|;|=)(?:-)?(?:\)|D|P))"

PATTERN = re.compile("|".join([FRAG_PATTERN, LINK_PATTERN, WORD_PATTERN, ALIAS_PATTERN, PUNCTUATION_PATTERN, SMILEY_PATTERN]))

def exclude_empty(x: tuple):
    return "".join(tuple(filter(lambda x: len(x) > 0, x)))

def re_tokenizer(text: str) -> List[str]:
    tokens = [exclude_empty(x) for x in PATTERN.findall(text) if len(x) > 0]
    return [_ for _ in tokens if _]

# %%
import nltk
from nltk.tokenize import TweetTokenizer

tk = TweetTokenizer()

def nltk_tweet_tokenizer(text: str) -> List[str]:
    return tk.tokenize(text)

# %% [markdown]
# Run your implementations on the data. Compare the results, decide which one is better. List the advantages of the best tokenizer.

# %%
with open("./Assignment1_data/file1", "r") as file:
    data = file.readlines()

# %%
print("White-space tokenizer:\n\n", *map(white_space_tokenizer, data), sep='\n')
# Out:
# White-space tokenizer:
#
#
# ['@anitapuspasari', 'waduh..']
# ['"', 'Could', 'journos', 'please', 'stop', 'putting', 'the', 'word', '""gate""', 'after', 'everything', 'they', 'write...', 'gate."']
# ['20%', 'More', 'Ridiculous', 'Sale', '@20x200', 'ends', 'tonight!', '-', 'get', '20%', 'off', 'by', 'entering', "'RIDONK'", 'at', 'checkout.', 'More', 'info:', 'http://bit.ly/ridonktues']
# ['@Studio85', 'I', 'have', 'a', 'pair', 'of', 'those', 'shoes.', 'They', 'are', 'comfy.', 'Like', 'being', 'barefoot.', 'Okay', 'for', 'running,', 'but', 'not', 'on', 'concrete,', 'as', "I've", 'discovered.']
# ['RT', '@twilightus', 'Team', 'Carlisle', 'is', 'a', 'Trending', 'Topic-', 'help', 'him', 'out', 'RT', 'Follow', '@peterfacinelli', 'see', 'a', 'grown', 'man', 'n', 'a', 'bikini', 'dance', 'Hollywood', 'Blvd']
# ['@karenrubin', 'you', 'might', 'have', 'to', 'reinstall', '-', 'that', 'happened', 'to', 'me', 'a', 'few', 'months', 'ago,', 'now', 'I', 'use', 'Nambu', 'on', 'my', 'Mac']
# ['Just', 'Posted:', 'Redneck', 'Dragon', '-', 'Part', 'XXVIII', '(http://cli.gs/gWy0yT)']
# ['"', '""Paul', 'McCartney', '...', 'went', 'through', 'all', 'his', 'education', 'there', 'and', 'nobody', 'thought', 'he', 'had', 'any', 'musical', 'talent,""', 'http://tinyurl.com/nkdbdq"']
# ['@ambienteer', 'Yeah,', 'pretty', 'much', 'how', 'i', 'feel', 'about', 'it.']
# ['@florianseroussi', 'Nothing', 'really', 'noticeable?', 'Are', 'you', 'kidding?']
# ['@toiletooth', 'Hours?']
# ['"', 'Obama,Hamas,and', 'the', 'Mullahs', 'being', '""helpfu', 'l""http://www.jpost.com/servlet/Satellite?cid=1245184848467&pagename=JPost%2FJPArticle%2FPrinter"']
# ['RT', '@BBHLabs', '81%', 'of', 'twitter', 'users', 'are', 'UNDER', '30', '+', 'more', 'v.', 'interesting', 'statistics', 'here:', 'http://www.sysomos.com/insidetwitter/']
# ['@Birdingperu', 'Great', 'looking', 'hummer!', 'RTThe', "world's", 'most', 'spectacular', 'hummingbird', 'Marvelous', 'Spatuletail', 'on', 'a', 'feeder.', 'http://bit.ly/aGHYZ']
# ['attn.', 'chas.', 'whitman:', 'RT', '@villagevoice', 'Jonas', 'Brothers', 'at', 'Rockefeller', 'Center', 'for', 'the', 'Today', 'Show', 'tomorrow', 'mornâ€”EEEEEEEEEE!']
# ['aw', 'fuck!', 'it', 'turns', 'out', 'you', "can't", 'defend', 'the', 'champagne', 'glass', 'hot', 'tub.']
# ['RT', '@ultimateAleks:', 'My', 'life', 'has', 'been', 'filled', 'with', 'terrible', 'misfortune;', 'most', 'of', 'which', 'never', 'happened.Montaigne', '~', 'So', 'true...']
# ['RT', '@weirdnews', 'The', 'Worldâ€™s', 'Smallest', 'Whale', 'Shark', '-', 'http://weirdasianews.com?p=4455']
# ['Hey', '@aaroncarter7', 'chrystina', 'and', 'cathee', 'with', 'two', "e's", 'love', 'you!', 'do', 'you', 'love', 'us?!!??!', '(AARONCARTERCELL', 'live', '>', 'http://ustre.am/3uyi)']
# ['*see']
# ['Live', 'forex', 'trading', '-', 'another', 'profitable', 'trade', 'with', 'Tflow', 'students', '...', 'http://u.mavrev.com/cflb']
# ['@TRAEvon', "I'm", 'putting', 'your', 'song', 'on', 'the', 'podcast', 'so', 'folks', 'can', 'check', 'you', 'out.', "I'll", 'give', 'the', 'myspace', 'site', 'as', 'well.']
# ['RT', '@melbpubcrawl:', 'RT', '@Tw1sty:', 'Another', 'random', 'thought:', '#tw1styiskingofthecastlekingofthebarstool', '#hashtagrebelalliance', '#damnwrongaccount']
# ['If', 'my', 'dog', 'should', 'go', 'blind', 'in', 'old', 'age,', 'would', 'it', 'be', 'kinder', 'to', 'have', 'him', 'put', 'to', 'sleep?', 'http://bit.ly/U3fBC']
# ['Just', 'purchased', '1', 'MP-443', 'Grach', 'http://140mafia.com', '#140mafia']
# ['@MDGonzales', 'Did', 'the', 'White', 'Sox', 'ever', 'actually', 'wear', 'these', 'unifroms,', 'are', 'are', 'they', 'just', 'throwback-inspired?']
# ['RT', '@AIESECLima:', 'AIESEC', 'Lima', '-', 'AIESEC', 'San', 'Marcos', 'EB', 'gather', 'at', "Juanjo's", '(LCP', 'Lima)', 'place.', 'http://bit.ly/eHJsH', 'http://bit.ly/jMBqX']
# ['If', 'an', 'innocent', 'girl', 'gets', 'shot', 'halfway', 'across', 'the', 'world,', 'does', 'she', 'make', 'a', 'sound?', 'Yes', 'the', 'whole', 'world', 'hears', 'her', '&', 'will', '#iranelection', '#neda', 'RT']
# ['RT', '@crackberrista:', 'RT', '@johkhz:', '@crackberrista', 'jejeje,', 'gracias', 'por', 'el', 'RT.', 'Vayan', 'pues', 'a', 'CDLR', '(CDR,', 'HPDLR)', 'QTPD,', 'jejeje', '#arribaespanol']
# ['Blessed', 'are', 'the', 'peacemakers,', 'for', 'they', 'shall', 'be', 'called', 'children', 'of', 'God.', 'Matthew', '5:9', '#scripture', '#peace', '#SemST']
# ['But', 'I', 'am', 'like', 'a', 'green', 'olive', 'tree', 'in', 'the', 'house', 'of', 'God;', 'I', 'will', 'trust', 'in', 'the', 'mercy', 'of', 'God', 'forever', 'and', 'ever', '-Ps.', '52:8', '#SemST']
# ['@musical_seizure', "It's", 'very', 'cool,', 'but', "it's", 'not', 'evidence', 'for', 'any', '#god.', 'Is', 'that', 'what', "you're", 'implying?', '#SemST']
# ['In', '#Christ', 'we', 'are', 'righteous,', 'and', 'in', 'practice,', 'we', 'are', 'being', 'conformed', 'to', 'His', 'image.~', 'Chip', 'Ingram', '#Quote', '#FB', '#TeamJesus', '#SemST']
# ['Greater', 'is', 'He', 'who', 'is', 'in', 'you', 'than', 'he', 'who', 'is', 'in', 'the', 'world.', '-', '1John', '4:4', '#god', '#bible', '#SemST']
# ['As', 'you', 'follow', 'Me,', 'I', 'lead', 'you', 'along', 'paths', 'of', 'newness:', 'ways', 'you', 'have', 'never', 'imagined.', '-', '@Jesus_Calling', '#SemST']
# ['Fill', 'your', 'church', 'with', 'holy', 'fascination', 'for', 'the', 'man', 'Christ', 'Jesus.', 'He', 'is', 'what', 'we', 'need.', '#worthy', '#onething', '#magnificent', '#obsession', '#SemST']
# ['It', 'will', 'never', 'get', 'old', 'to', 'hear', 'when', 'Christians', 'lead', 'others', 'to', 'ultimate', 'love', '&', 'hope!', '#disciples', '#share', '#gospel', '#JesusChangesEverything', '#SemST']
# ['Religious', 'people', 'are', 'people', 'too......', 'Just', 'bigoted,genitalia', 'mutilating,', 'angry', 'gullible', 'people', '#SemST']
# ['That', 'nagging', 'doubt', 'you', 'keep', 'having', 'about', 'god?', 'Gods', 'not', 'testing', 'u,', "it's", 'your', 'intellect', 'trying', 'to', 'tell', 'you', 'your', 'beliefs', 'are', 'bullshit.', '#SemST']
# ['God', 'is', 'so', 'good!', 'All', 'the', 'praises', 'go', 'up', 'to', 'Him!', '#SemST']
# ['@xfranman', 'Old', 'age', 'has', 'not', 'made', 'you', 'any', 'wiser', 'or', 'more', 'mature.', 'For', 'shame!', '#SemST']
# ['@HijabiSmile', '@NAInfidels', '@captains_pick', '@Pinchey1964', 'Both', 'are', 'utterly', 'stupid', 'and', 'useless', 'anyway.', '#liberalism', '#democracy', '#SemST']
# ['All', 'we', 'need', 'is', 'to', 'go', 'back', 'to', 'our', 'roots', 'and', 'get', 'closer', 'to', 'nature.', '#simplelife', '#liveeasy', '#foodforall', '#goslow', '#SemST']
# ["'Pop", 'may', 'throw', 'in', 'the', 'towel', 'second', 'half..', '#SemST']

# %%
print("Sentencepiece tokenizer:\n\n", *map(sentencepiece_wrapper, data), sep='\n')
# Out:
# Sentencepiece tokenizer:
#
#
# ['▁@', 'an', 'it', 'a', 'p', 'u', 'spa', 's', 'ar', 'i', '▁wa', 'd', 'u', 'h', '.', '.']
# ['▁"', '▁C', 'ou', 'ld', '▁', 'jo', 'ur', 'no', 's', '▁pleas', 'e', '▁sto', 'p', '▁put', 'ting', '▁the', '▁', 'w', 'ord', '▁""', 'gate', '""', '▁a', 'f', 'ter', '▁every', 'th', 'ing', '▁the', 'y', '▁', 'w', 'r', 'ite', '...', '▁', 'gate', '.', '"']
# ['▁2', '0', '%', '▁Mo', 're', '▁R', 'id', 'icul', 'ous', '▁Sale', '▁@', '2', '0', 'x', '200', '▁', 'end', 's', '▁tonight', '!', '▁-', '▁get', '▁2', '0', '%', '▁of', 'f', '▁b', 'y', '▁', 'enter', 'ing', '▁', "'", 'R', 'I', 'D', 'ON', 'K', "'", '▁at', '▁check', 'out', '.', '▁Mo', 're', '▁in', 'f', 'o', ':', '▁', 'ht', 'tp', '://', 'bit', '.', 'ly', '/', 'ri', 'd', 'on', 'k', 't', 'ues']
# ['▁@', 'S', 't', 'udio', '8', '5', '▁I', '▁hav', 'e', '▁a', '▁p', 'air', '▁of', '▁', 'th', 'ose', '▁sho', 'es', '.', '▁The', 'y', '▁are', '▁', 'com', 'f', 'y', '.', '▁Li', 'ke', '▁be', 'ing', '▁', 'ba', 're', 'f', 'o', 'o', 't', '.', '▁O', 'k', 'a', 'y', '▁for', '▁', 'r', 'unn', 'ing', ',', '▁bu', 't', '▁not', '▁on', '▁con', 'c', 're', 't', 'e', ',', '▁a', 's', '▁I', "'", 've', '▁', 'disc', 'over', 'ed', '.']
# ['▁RT', '▁@', 'tw', 'i', 'light', 'us', '▁', 'Team', '▁C', 'ar', 'li', 's', 'le', '▁is', '▁a', '▁T', 'r', 'end', 'ing', '▁To', 'pic', '-', '▁', 'help', '▁h', 'im', '▁out', '▁RT', '▁F', 'o', 'l', 'low', '▁@', 'p', 'e', 'ter', 'facin', 'el', 'li', '▁se', 'e', '▁a', '▁g', 'r', 'own', '▁', 'man', '▁n', '▁a', '▁b', 'ik', 'in', 'i', '▁', 'd', 'ance', '▁Ho', 'll', 'y', 'w', 'ood', '▁Bl', 'v', 'd']
# ['▁@', 'k', 'ar', 'en', 'r', 'ub', 'in', '▁you', '▁mi', 'g', 'ht', '▁hav', 'e', '▁to', '▁', 're', 'in', 'st', 'all', '▁-', '▁that', '▁happened', '▁to', '▁me', '▁a', '▁fe', 'w', '▁mo', 'n', 'th', 's', '▁', 'ago', ',', '▁no', 'w', '▁I', '▁use', '▁N', 'am', 'b', 'u', '▁on', '▁my', '▁', 'Mac']
# ['▁Ju', 'st', '▁', 'Post', 'ed', ':', '▁Re', 'd', 'ne', 'ck', '▁D', 'r', 'ago', 'n', '▁-', '▁', 'P', 'art', '▁', 'X', 'X', 'V', 'I', 'I', 'I', '▁(', 'ht', 'tp', '://', 'cli', '.', 'g', 's', '/', 'g', 'W', 'y', '0', 'y', 'T', ')']
# ['▁"', '▁""', 'P', 'a', 'ul', '▁M', 'c', 'C', 'art', 'ne', 'y', '▁', '...', '▁we', 'nt', '▁', 't', 'hrough', '▁', 'all', '▁h', 'is', '▁', 'educ', 'at', 'ion', '▁there', '▁', 'and', '▁no', 'b', 'o', 'd', 'y', '▁thought', '▁he', '▁h', 'ad', '▁any', '▁', 'musical', '▁ta', 'lent', ',', '""', '▁', 'ht', 'tp', '://', 'tiny', 'ur', 'l', '.', 'com', '/', 'nk', 'd', 'b', 'd', 'q', '"']
# ['▁@', 'am', 'bi', 'ent', 'e', 'er', '▁Ye', 'ah', ',', '▁p', 'rett', 'y', '▁mu', 'ch', '▁ho', 'w', '▁i', '▁fee', 'l', '▁a', 'b', 'out', '▁it', '.']
# ['▁@', 'f', 'lo', 'ri', 'an', 'ser', 'ous', 's', 'i', '▁N', 'oth', 'ing', '▁real', 'ly', '▁not', 'ice', 'able', '?', '▁A', 're', '▁you', '▁', 'k', 'id', 'd', 'ing', '?']
# ['▁@', 'to', 'ile', 'to', 'oth', '▁Ho', 'ur', 's', '?']
# ['▁"', '▁O', 'b', 'ama', ',', 'H', 'ama', 's', ',', 'and', '▁the', '▁M', 'u', 'll', 'ah', 's', '▁be', 'ing', '▁""', 'help', 'f', 'u', '▁', 'l', '""', 'ht', 'tp', '://', 'ww', 'w', '.', 'j', 'p', 'o', 'st', '.', 'com', '/', 'ser', 'v', 'le', 't', '/', 'S', 'a', 'tell', 'ite', '?', 'c', 'id', '=', '1', '2', '45', '1', '8', '4', '8', '4', '8', '4', '67', '&', 'pag', 'ename', '=', 'J', 'Post', '%', '2', 'F', 'J', 'P', 'A', 'r', 't', 'icle', '%', '2', 'F', 'P', 'r', 'in', 'ter', '"']
# ['▁RT', '▁@', 'B', 'B', 'H', 'L', 'a', 'b', 's', '▁', '8', '1', '%', '▁of', '▁', 'twitter', '▁use', 'r', 's', '▁are', '▁', 'U', 'N', 'D', 'ER', '▁', '3', '0', '▁', '+', '▁mo', 're', '▁', 'v', '.', '▁in', 'ter', 'est', 'ing', '▁stat', 'i', 'st', 'ics', '▁he', 're', ':', '▁', 'ht', 'tp', '://', 'ww', 'w', '.', 's', 'y', 's', 'om', 'o', 's', '.', 'com', '/', 'ins', 'ide', 'twitter', '/']
# ['▁@', 'B', 'ird', 'ing', 'p', 'er', 'u', '▁Great', '▁', 'lo', 'o', 'k', 'ing', '▁h', 'u', 'm', 'm', 'er', '!', '▁RT', 'The', '▁world', "'", 's', '▁mo', 'st', '▁spe', 'ct', 'ac', 'ul', 'ar', '▁h', 'u', 'm', 'm', 'ing', 'b', 'ird', '▁', 'Mar', 've', 'l', 'ous', '▁S', 'p', 'at', 'ul', 'e', 'tai', 'l', '▁on', '▁a', '▁fee', 'd', 'er', '.', '▁', 'ht', 'tp', '://', 'bit', '.', 'ly', '/', 'a', 'G', 'H', 'Y', 'Z']
# ['▁at', 't', 'n', '.', '▁', 'chas', '.', '▁wh', 'it', 'man', ':', '▁RT', '▁@', 'v', 'ill', 'age', 'v', 'o', 'ice', '▁', 'J', 'on', 'as', '▁B', 'r', 'other', 's', '▁at', '▁R', 'o', 'ck', 'e', 'f', 'e', 'll', 'er', '▁C', 'enter', '▁for', '▁the', '▁To', 'day', '▁Sh', 'ow', '▁to', 'm', 'o', 'r', 'r', 'ow', '▁mo', 'r', 'n', 'â€”', 'E', 'E', 'E', 'E', 'E', 'E', 'E', 'E', 'E', 'E', '!']
# ['▁a', 'w', '▁', 'f', 'u', 'ck', '!', '▁it', '▁', 't', 'ur', 'n', 's', '▁out', '▁you', '▁can', "'", 't', '▁de', 'f', 'end', '▁the', '▁', 'ch', 'am', 'pag', 'ne', '▁g', 'lass', '▁ho', 't', '▁', 't', 'ub', '.']
# ['▁RT', '▁@', 'ultimate', 'A', 'le', 'k', 's', ':', '▁M', 'y', '▁', 'life', '▁has', '▁be', 'en', '▁fi', 'll', 'ed', '▁wi', 'th', '▁', 'ter', 'ri', 'ble', '▁mi', 's', 'for', 't', 'u', 'ne', ';', '▁mo', 'st', '▁of', '▁wh', 'i', 'ch', '▁n', 'ever', '▁happened', '.', 'M', 'on', 'tai', 'g', 'ne', '▁', '~', '▁S', 'o', '▁', 't', 'rue', '...']
# ['▁RT', '▁@', 'weird', 'news', '▁The', '▁W', 'orld', 'â€', 'T', 'M', 's', '▁S', 'm', 'all', 'est', '▁Wh', 'al', 'e', '▁Sh', 'ar', 'k', '▁-', '▁', 'ht', 'tp', '://', 'weird', 'as', 'i', 'a', 'news', '.', 'com', '?', 'p', '=', '4', '45', '5']
# ['▁He', 'y', '▁@', 'a', 'ar', 'on', 'car', 'ter', '7', '▁', 'ch', 'r', 'y', 'st', 'in', 'a', '▁', 'and', '▁', 'ca', 'the', 'e', '▁wi', 'th', '▁', 'tw', 'o', '▁', 'e', "'", 's', '▁', 'love', '▁you', '!', '▁do', '▁you', '▁', 'love', '▁', 'us', '?!', '!', '?', '?!', '▁(', 'A', 'AR', 'ON', 'C', 'AR', 'T', 'ER', 'C', 'E', 'L', 'L', '▁', 'live', '▁', '>', '▁', 'ht', 'tp', '://', 'ust', 're', '.', 'am', '/', '3', 'u', 'y', 'i', ')']
# ['▁', '*', 'se', 'e']
# ['▁Li', 've', '▁for', 'e', 'x', '▁trad', 'ing', '▁-', '▁', 'an', 'other', '▁pro', 'f', 'it', 'able', '▁trad', 'e', '▁wi', 'th', '▁T', 'f', 'low', '▁stu', 'd', 'ent', 's', '▁', '...', '▁', 'ht', 'tp', '://', 'u', '.', 'ma', 'v', 're', 'v', '.', 'com', '/', 'c', 'f', 'lb']
# ['▁@', 'T', 'R', 'A', 'E', 'v', 'on', '▁I', "'", 'm', '▁put', 'ting', '▁you', 'r', '▁song', '▁on', '▁the', '▁po', 'd', 'cast', '▁so', '▁', 'f', 'o', 'l', 'k', 's', '▁can', '▁check', '▁you', '▁out', '.', '▁I', "'", 'll', '▁gi', 've', '▁the', '▁my', 'spa', 'ce', '▁s', 'ite', '▁a', 's', '▁we', 'll', '.']
# ['▁RT', '▁@', 'm', 'el', 'b', 'p', 'ub', 'c', 'r', 'a', 'w', 'l', ':', '▁RT', '▁@', 'Tw', '1', 'st', 'y', ':', '▁A', 'n', 'other', '▁rand', 'om', '▁thought', ':', '▁#', 'tw', '1', 'st', 'y', 'is', 'kingofthe', 'cast', 'le', 'kingofthe', 'b', 'ar', 'st', 'o', 'o', 'l', '▁#', 'h', 'asht', 'agr', 'e', 'b', 'el', 'all', 'i', 'ance', '▁#', 'd', 'am', 'n', 'w', 'r', 'on', 'g', 'ac', 'co', 'unt']
# ['▁I', 'f', '▁my', '▁do', 'g', '▁sho', 'ul', 'd', '▁go', '▁b', 'li', 'nd', '▁in', '▁', 'o', 'ld', '▁', 'age', ',', '▁', 'w', 'ou', 'ld', '▁it', '▁be', '▁kind', 'er', '▁to', '▁hav', 'e', '▁h', 'im', '▁put', '▁to', '▁s', 'le', 'e', 'p', '?', '▁', 'ht', 'tp', '://', 'bit', '.', 'ly', '/', 'U', '3', 'f', 'B', 'C']
# ['▁Ju', 'st', '▁p', 'ur', 'chas', 'ed', '▁1', '▁M', 'P', '-', '4', '4', '3', '▁G', 'r', 'ach', '▁', 'ht', 'tp', '://', '1', '4', '0', 'mafia', '.', 'com', '▁#', '1', '4', '0', 'mafia']
# ['▁@', 'M', 'D', 'G', 'on', 'z', 'al', 'es', '▁D', 'id', '▁the', '▁Wh', 'ite', '▁S', 'o', 'x', '▁', 'ever', '▁act', 'u', 'all', 'y', '▁we', 'ar', '▁these', '▁u', 'ni', 'from', 's', ',', '▁are', '▁are', '▁the', 'y', '▁j', 'ust', '▁throw', 'back', '-', 'ins', 'p', 'i', 're', 'd', '?']
# ['▁RT', '▁@', 'AIESEC', 'Lima', ':', '▁', 'AIESEC', '▁', 'Lima', '▁-', '▁', 'AIESEC', '▁S', 'an', '▁', 'Mar', 'co', 's', '▁', 'E', 'B', '▁g', 'a', 'th', 'er', '▁at', '▁Ju', 'an', 'jo', "'", 's', '▁(', 'L', 'C', 'P', '▁', 'Lima', ')', '▁p', 'la', 'ce', '.', '▁', 'ht', 'tp', '://', 'bit', '.', 'ly', '/', 'e', 'H', 'J', 's', 'H', '▁', 'ht', 'tp', '://', 'bit', '.', 'ly', '/', 'j', 'MB', 'q', 'X']
# ['▁I', 'f', '▁', 'an', '▁in', 'no', 'c', 'ent', '▁gi', 'r', 'l', '▁get', 's', '▁sho', 't', '▁half', 'way', '▁', 'ac', 'r', 'o', 's', 's', '▁the', '▁world', ',', '▁do', 'es', '▁sh', 'e', '▁', 'make', '▁a', '▁s', 'ound', '?', '▁Ye', 's', '▁the', '▁who', 'le', '▁world', '▁hear', 's', '▁he', 'r', '▁', '&', '▁wi', 'll', '▁#', 'iranelection', '▁#', 'n', 'ed', 'a', '▁RT']
# ['▁RT', '▁@', 'crackberrista', ':', '▁RT', '▁@', 'jo', 'h', 'k', 'h', 'z', ':', '▁@', 'crackberrista', '▁jejeje', ',', '▁grac', 'i', 'as', '▁po', 'r', '▁', 'el', '▁RT', '.', '▁', 'V', 'a', 'y', 'an', '▁p', 'ues', '▁a', '▁C', 'DLR', '▁(', 'C', 'D', 'R', ',', '▁H', 'P', 'DLR', ')', '▁', 'Q', 'T', 'P', 'D', ',', '▁jejeje', '▁#', 'ar', 'ri', 'ba', 'e', 'spa', 'no', 'l']
# ['▁Bl', 'ess', 'ed', '▁are', '▁the', '▁', 'peace', 'make', 'r', 's', ',', '▁for', '▁the', 'y', '▁sh', 'all', '▁be', '▁', 'c', 'all', 'ed', '▁chi', 'ld', 'r', 'en', '▁of', '▁God', '.', '▁M', 'at', 'the', 'w', '▁', '5', ':', '9', '▁#', 's', 'c', 'ri', 'p', 'ture', '▁#', 'peace', '▁#', 'SemST']
# ['▁Bu', 't', '▁I', '▁', 'am', '▁li', 'ke', '▁a', '▁green', '▁', 'o', 'live', '▁', 't', 'ree', '▁in', '▁the', '▁ho', 'use', '▁of', '▁God', ';', '▁I', '▁wi', 'll', '▁', 't', 'r', 'ust', '▁in', '▁the', '▁me', 'r', 'c', 'y', '▁of', '▁God', '▁for', 'ever', '▁', 'and', '▁', 'ever', '▁-', 'P', 's', '.', '▁', '5', '2', ':', '8', '▁#', 'SemST']
# ['▁@', 'musical', '_', 'se', 'i', 'z', 'u', 're', '▁It', "'", 's', '▁', 'very', '▁cool', ',', '▁bu', 't', '▁it', "'", 's', '▁not', '▁ev', 'ide', 'nce', '▁for', '▁any', '▁#', 'god', '.', '▁I', 's', '▁that', '▁wh', 'at', '▁you', "'", 're', '▁', 'im', 'p', 'ly', 'ing', '?', '▁#', 'SemST']
# ['▁In', '▁#', 'Christ', '▁we', '▁are', '▁', 'righte', 'ous', ',', '▁', 'and', '▁in', '▁pra', 'ct', 'ice', ',', '▁we', '▁are', '▁be', 'ing', '▁con', 'for', 'm', 'ed', '▁to', '▁H', 'is', '▁image', '.', '~', '▁C', 'hip', '▁I', 'ng', 'r', 'am', '▁#', 'Q', 'u', 'o', 't', 'e', '▁#', 'F', 'B', '▁#', 'Team', 'Jesus', '▁#', 'SemST']
# ['▁Great', 'er', '▁is', '▁He', '▁who', '▁is', '▁in', '▁you', '▁than', '▁he', '▁who', '▁is', '▁in', '▁the', '▁world', '.', '▁-', '▁1', 'J', 'o', 'h', 'n', '▁', '4', ':', '4', '▁#', 'god', '▁#', 'bi', 'ble', '▁#', 'SemST']
# ['▁A', 's', '▁you', '▁follow', '▁M', 'e', ',', '▁I', '▁lea', 'd', '▁you', '▁a', 'lo', 'ng', '▁p', 'a', 'th', 's', '▁of', '▁new', 'n', 'ess', ':', '▁way', 's', '▁you', '▁hav', 'e', '▁n', 'ever', '▁i', 'ma', 'g', 'in', 'ed', '.', '▁-', '▁@', 'Jesus', '_', 'C', 'all', 'ing', '▁#', 'SemST']
# ['▁F', 'ill', '▁you', 'r', '▁church', '▁wi', 'th', '▁ho', 'ly', '▁fas', 'c', 'in', 'at', 'ion', '▁for', '▁the', '▁', 'man', '▁', 'Christ', '▁', 'Jesus', '.', '▁He', '▁is', '▁wh', 'at', '▁we', '▁need', '.', '▁#', 'w', 'o', 'r', 'th', 'y', '▁#', 'one', 'th', 'ing', '▁#', 'ma', 'g', 'ni', 'f', 'ice', 'nt', '▁#', 'o', 'b', 's', 'ess', 'ion', '▁#', 'SemST']
# ['▁It', '▁wi', 'll', '▁n', 'ever', '▁get', '▁', 'o', 'ld', '▁to', '▁hear', '▁wh', 'en', '▁', 'Christ', 'i', 'an', 's', '▁lea', 'd', '▁', 'other', 's', '▁to', '▁', 'ultimate', '▁', 'love', '▁', '&', '▁ho', 'p', 'e', '!', '▁#', 'disc', 'i', 'ple', 's', '▁#', 'sha', 're', '▁#', 'gos', 'p', 'el', '▁#', 'Jesus', 'C', 'hange', 's', 'E', 'very', 'th', 'ing', '▁#', 'SemST']
# ['▁Religio', 'us', '▁pe', 'o', 'ple', '▁are', '▁pe', 'o', 'ple', '▁to', 'o', '...', '...', '▁Ju', 'st', '▁b', 'igo', 't', 'ed', ',', 'g', 'en', 'it', 'alia', '▁mu', 't', 'i', 'la', 'ting', ',', '▁a', 'ng', 'r', 'y', '▁g', 'ul', 'li', 'ble', '▁pe', 'o', 'ple', '▁#', 'SemST']
# ['▁Tha', 't', '▁na', 'ggin', 'g', '▁do', 'ub', 't', '▁you', '▁', 'ke', 'e', 'p', '▁hav', 'ing', '▁a', 'b', 'out', '▁', 'god', '?', '▁God', 's', '▁not', '▁', 't', 'est', 'ing', '▁u', ',', '▁it', "'", 's', '▁you', 'r', '▁in', 'tell', 'ect', '▁try', 'ing', '▁to', '▁', 'tell', '▁you', '▁you', 'r', '▁belie', 'f', 's', '▁are', '▁bu', 'll', 's', 'h', 'it', '.', '▁#', 'SemST']
# ['▁God', '▁is', '▁so', '▁g', 'ood', '!', '▁A', 'll', '▁the', '▁pra', 'is', 'es', '▁go', '▁u', 'p', '▁to', '▁H', 'im', '!', '▁#', 'SemST']
# ['▁@', 'x', 'fran', 'man', '▁O', 'ld', '▁', 'age', '▁has', '▁not', '▁ma', 'd', 'e', '▁you', '▁any', '▁wi', 'ser', '▁', 'o', 'r', '▁mo', 're', '▁ma', 'ture', '.', '▁', 'For', '▁sh', 'ame', '!', '▁#', 'SemST']
# ['▁@', 'Hi', 'ja', 'bi', 'S', 'm', 'ile', '▁@', 'N', 'A', 'I', 'n', 'f', 'ide', 'l', 's', '▁@', 'cap', 't', 'a', 'ins', '_', 'pic', 'k', '▁@', 'P', 'i', 'nche', 'y', '1', '9', '6', '4', '▁B', 'oth', '▁are', '▁u', 't', 'ter', 'ly', '▁stu', 'p', 'id', '▁', 'and', '▁use', 'l', 'ess', '▁any', 'way', '.', '▁#', 'li', 'b', 'er', 'al', 'is', 'm', '▁#', 'd', 'e', 'm', 'o', 'crac', 'y', '▁#', 'SemST']
# ['▁A', 'll', '▁we', '▁need', '▁is', '▁to', '▁go', '▁', 'back', '▁to', '▁', 'o', 'ur', '▁roo', 't', 's', '▁', 'and', '▁get', '▁', 'c', 'lo', 'ser', '▁to', '▁na', 'ture', '.', '▁#', 's', 'im', 'ple', 'life', '▁#', 'live', 'e', 'as', 'y', '▁#', 'food', 'for', 'all', '▁#', 'gos', 'low', '▁#', 'SemST']
# ['▁', "'", 'P', 'o', 'p', '▁may', '▁throw', '▁in', '▁the', '▁to', 'w', 'el', '▁se', 'co', 'nd', '▁half', '.', '.', '▁#', 'SemST']

# %%
print("Regexp tokenizer:\n\n", *map(re_tokenizer, data), sep='\n')
# Out:
# Regexp tokenizer:
#
#
# ['@anitapuspasari', 'waduh', '.', '.']
# ['"', 'Could', 'journos', 'please', 'stop', 'putting', 'the', 'word', '"', '"', 'gate', '"', '"', 'after', 'everything', 'they', 'write', '.', '.', '.', 'gate', '.', '"']
# ['20', 'More', 'Ridiculous', 'Sale', '@20x200', 'ends', 'tonight', '!', '-', 'get', '20', 'off', 'by', 'entering', "'", 'RIDONK', "'", 'at', 'checkout', '.', 'More', 'info', ':', 'http://bit.ly/ridonktues']
# ['@Studio85', 'I h', 'ave', 'a p', 'air', 'of', 'those', 'shoes', '.', 'They', 'are', 'comfy', '.', 'Like', 'being', 'barefoot', '.', 'Okay', 'for', 'running', ',', 'but', 'not', 'on', 'concrete', ',', 'as', 'I', "'ve", 'discovered', '.']
# ['RT', '@twilightus', 'Team', 'Carlisle', 'is', 'a T', 'rending', 'Topic', '-', 'help', 'him', 'out', 'RT', 'Follow', '@peterfacinelli', 'see', 'a g', 'rown', 'man', 'n a b', 'ikini', 'dance', 'Hollywood', 'Blvd']
# ['@karenrubin', 'you', 'might', 'have', 'to', 'reinstall', '-', 'that', 'happened', 'to', 'me', 'a f', 'ew', 'months', 'ago', ',', 'now', 'I u', 'se', 'Nambu', 'on', 'my', 'Mac']
# ['Just', 'Posted', ':', 'Redneck', 'Dragon', '-', 'Part', 'XXVIII', '(', 'http://cli.gs/gWy0yT', ')']
# ['"', '"', '"', 'Paul', 'McCartney', '.', '.', '.', 'went', 'through', 'all', 'his', 'education', 'there', 'and', 'nobody', 'thought', 'he', 'had', 'any', 'musical', 'talent', ',', '"', '"', 'http://tinyurl.com/nkdbdq', '"']
# ['@ambienteer', 'Yeah', ',', 'pretty', 'much', 'how', 'i f', 'eel', 'about', 'it', '.']
# ['@florianseroussi', 'Nothing', 'really', 'noticeable', '?', 'Are', 'you', 'kidding', '?']
# ['@toiletooth', 'Hours', '?']
# ['"', 'Obama', ',', 'Hamas', ',', 'and', 'the', 'Mullahs', 'being', '"', '"', 'helpfu', 'l', '"', '"', 'http://www.jpost.com/servlet/Satellite?cid', '1245184848467', 'pagename', 'JPost', '2FJPArticle', '2FPrinter', '"']
# ['RT', '@BBHLabs', '81', 'of', 'twitter', 'users', 'are', 'UNDER', '30', 'more', 'v', '.', 'interesting', 'statistics', 'here', ':', 'http://www.sysomos.com/insidetwitter/']
# ['@Birdingperu', 'Great', 'looking', 'hummer', '!', 'RTThe', 'world', "'s", 'most', 'spectacular', 'hummingbird', 'Marvelous', 'Spatuletail', 'on', 'a f', 'eeder', '.', 'http://bit.ly/aGHYZ']
# ['attn', '.', 'chas', '.', 'whitman', ':', 'RT', '@villagevoice', 'Jonas', 'Brothers', 'at', 'Rockefeller', 'Center', 'for', 'the', 'Today', 'Show', 'tomorrow', 'mornâ', 'EEEEEEEEEE', '!']
# ['aw', 'fuck', '!', 'it', 'turns', 'out', 'you', 'ca', "n't", 'defend', 'the', 'champagne', 'glass', 'hot', 'tub', '.']
# ['RT', '@ultimateAleks', ':', 'My', 'life', 'has', 'been', 'filled', 'with', 'terrible', 'misfortune', ';', 'most', 'of', 'which', 'never', 'happened', '.', 'Montaigne', 'So', 'true', '.', '.', '.']
# ['RT', '@weirdnews', 'The', 'Worldâ', 's S', 'mallest', 'Whale', 'Shark', '-', 'http://weirdasianews.com?p', '4455']
# ['Hey', '@aaroncarter7', 'chrystina', 'and', 'cathee', 'with', 'two', 'e', "'s", 'love', 'you', '!', 'do', 'you', 'love', 'us', '?', '!', '!', '?', '?', '!', '(', 'AARONCARTERCELL', 'live', 'http://ustre.am/3uyi', ')']
# ['see']
# ['Live', 'forex', 'trading', '-', 'another', 'profitable', 'trade', 'with', 'Tflow', 'students', '.', '.', '.', 'http://u.mavrev.com/cflb']
# ['@TRAEvon', 'I', "'", 'm p', 'utting', 'your', 'song', 'on', 'the', 'podcast', 'so', 'folks', 'can', 'check', 'you', 'out', '.', 'I', "'ll", 'give', 'the', 'myspace', 'site', 'as', 'well', '.']
# ['RT', '@melbpubcrawl', ':', 'RT', '@Tw1sty', ':', 'Another', 'random', 'thought', ':', '#tw1styiskingofthecastlekingofthebarstool', '#hashtagrebelalliance', '#damnwrongaccount']
# ['If', 'my', 'dog', 'should', 'go', 'blind', 'in', 'old', 'age', ',', 'would', 'it', 'be', 'kinder', 'to', 'have', 'him', 'put', 'to', 'sleep', '?', 'http://bit.ly/U3fBC']
# ['Just', 'purchased', '1 M', 'P', '-', '443', 'Grach', 'http://140mafia.com', '#140mafia']
# ['@MDGonzales', 'Did', 'the', 'White', 'Sox', 'ever', 'actually', 'wear', 'these', 'unifroms', ',', 'are', 'are', 'they', 'just', 'throwback', '-', 'inspired', '?']
# ['RT', '@AIESECLima', ':', 'AIESEC', 'Lima', '-', 'AIESEC', 'San', 'Marcos', 'EB', 'gather', 'at', 'Juanjo', "'s", '(', 'LCP', 'Lima', ')', 'place', '.', 'http://bit.ly/eHJsH', 'http://bit.ly/jMBqX']
# ['If', 'an', 'innocent', 'girl', 'gets', 'shot', 'halfway', 'across', 'the', 'world', ',', 'does', 'she', 'make', 'a s', 'ound', '?', 'Yes', 'the', 'whole', 'world', 'hears', 'her', 'will', '#iranelection', '#neda', 'RT']
# ['RT', '@crackberrista', ':', 'RT', '@johkhz', ':', '@crackberrista', 'jejeje', ',', 'gracias', 'por', 'el', 'RT', '.', 'Vayan', 'pues', 'a C', 'DLR', '(', 'CDR', ',', 'HPDLR', ')', 'QTPD', ',', 'jejeje', '#arribaespanol']
# ['Blessed', 'are', 'the', 'peacemakers', ',', 'for', 'they', 'shall', 'be', 'called', 'children', 'of', 'God', '.', 'Matthew', '5', ':', '9', '#scripture', '#peace', '#SemST']
# ['But', 'I a', 'm l', 'ike', 'a g', 'reen', 'olive', 'tree', 'in', 'the', 'house', 'of', 'God', ';', 'I w', 'ill', 'trust', 'in', 'the', 'mercy', 'of', 'God', 'forever', 'and', 'ever', '-', 'Ps', '.', '52', ':', '8', '#SemST']
# ['@musical_seizure', 'It', "'s", 'very', 'cool', ',', 'but', 'it', "'s", 'not', 'evidence', 'for', 'any', '#god', '.', 'Is', 'that', 'what', 'you', "'re", 'implying', '?', '#SemST']
# ['In', '#Christ', 'we', 'are', 'righteous', ',', 'and', 'in', 'practice', ',', 'we', 'are', 'being', 'conformed', 'to', 'His', 'image', '.', 'Chip', 'Ingram', '#Quote', '#FB', '#TeamJesus', '#SemST']
# ['Greater', 'is', 'He', 'who', 'is', 'in', 'you', 'than', 'he', 'who', 'is', 'in', 'the', 'world', '.', '-', '1John', '4', ':', '4', '#god', '#bible', '#SemST']
# ['As', 'you', 'follow', 'Me', ',', 'I l', 'ead', 'you', 'along', 'paths', 'of', 'newness', ':', 'ways', 'you', 'have', 'never', 'imagined', '.', '-', '@Jesus_Calling', '#SemST']
# ['Fill', 'your', 'church', 'with', 'holy', 'fascination', 'for', 'the', 'man', 'Christ', 'Jesus', '.', 'He', 'is', 'what', 'we', 'need', '.', '#worthy', '#onething', '#magnificent', '#obsession', '#SemST']
# ['It', 'will', 'never', 'get', 'old', 'to', 'hear', 'when', 'Christians', 'lead', 'others', 'to', 'ultimate', 'love', 'hope', '!', '#disciples', '#share', '#gospel', '#JesusChangesEverything', '#SemST']
# ['Religious', 'people', 'are', 'people', 'too', '.', '.', '.', '.', '.', '.', 'Just', 'bigoted', ',', 'genitalia', 'mutilating', ',', 'angry', 'gullible', 'people', '#SemST']
# ['That', 'nagging', 'doubt', 'you', 'keep', 'having', 'about', 'god', '?', 'Gods', 'not', 'testing', 'u', ',', 'it', "'s", 'your', 'intellect', 'trying', 'to', 'tell', 'you', 'your', 'beliefs', 'are', 'bullshit', '.', '#SemST']
# ['God', 'is', 'so', 'good', '!', 'All', 'the', 'praises', 'go', 'up', 'to', 'Him', '!', '#SemST']
# ['@xfranman', 'Old', 'age', 'has', 'not', 'made', 'you', 'any', 'wiser', 'or', 'more', 'mature', '.', 'For', 'shame', '!', '#SemST']
# ['@HijabiSmile', '@NAInfidels', '@captains_pick', '@Pinchey1964', 'Both', 'are', 'utterly', 'stupid', 'and', 'useless', 'anyway', '.', '#liberalism', '#democracy', '#SemST']
# ['All', 'we', 'need', 'is', 'to', 'go', 'back', 'to', 'our', 'roots', 'and', 'get', 'closer', 'to', 'nature', '.', '#simplelife', '#liveeasy', '#foodforall', '#goslow', '#SemST']
# ["'", 'Pop', 'may', 'throw', 'in', 'the', 'towel', 'second', 'half', '.', '.', '#SemST']

# %%
re_tokenizer("@xfranman Old age has made N A T O!")
# Out:
# ['@xfranman', 'Old', 'age', 'has', 'made', 'N A T O', '!']

# %% [markdown]
# White-space tokenizer is the simplest and least effective, but it provides a valuable baseline since ~90% of tokens might be well separated by spaces. Regexp tokenizer is advantageous and flexible tool that works almost perfect, tokenizing valuable language aspects and twitter-specific things. However, writing regexp is not a trivial task and thus it is quite an error prone approach. Sentencepiece is a totally 3different tokenizer: actually, it is a model that builds a vocabulary by learning it from the text. It fills vocabulary with frequent tokens that are not limited to just words, but parts of sententences which may include words combinations or their parts.
# The most useful tokenizer is NLTK tweeter tokenizer which comprises of complex and large regex patterns which are much more accurate than the ones introduced by me.

# %% [markdown]
# ## Stemming and Lemmatization
#
# Your task is to write two functions: stem and lemmatize. Input is a text, so you need to tokenize it first.

# %%
from nltk.stem.snowball import SnowballStemmer

stemmer = SnowballStemmer("english")

def stem(text: str) -> List[str]:
    tokens = list(map(nltk_tweet_tokenizer, text))
    all_tokens = []
    for x in tokens:
        all_tokens.extend(x)
    return list(map(stemmer.stem, all_tokens))

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

def lemmatize(text: str) -> List[str]:
    return list(map(lambda x: x.lemma_, nlp(text)))

# %%
stem(data)
# Out:
# ['@anitapuspasari',
#  'waduh',
#  '..',
#  '"',
#  'could',
#  'journo',
#  'pleas',
#  'stop',
#  'put',
#  'the',
#  'word',
#  '"',
#  '"',
#  'gate',
#  '"',
#  '"',
#  'after',
#  'everyth',
#  'they',
#  'write',
#  '...',
#  'gate',
#  '.',
#  '"',
#  '20',
#  '%',
#  'more',
#  'ridicul',
#  'sale',
#  '@20x200',
#  'end',
#  'tonight',
#  '!',
#  '-',
#  'get',
#  '20',
#  '%',
#  'off',
#  'by',
#  'enter',
#  "'",
#  'ridonk',
#  "'",
#  'at',
#  'checkout',
#  '.',
#  'more',
#  'info',
#  ':',
#  'http://bit.ly/ridonktu',
#  '@studio85',
#  'i',
#  'have',
#  'a',
#  'pair',
#  'of',
#  'those',
#  'shoe',
#  '.',
#  'they',
#  'are',
#  'comfi',
#  '.',
#  'like',
#  'be',
#  'barefoot',
#  '.',
#  'okay',
#  'for',
#  'run',
#  ',',
#  'but',
#  'not',
#  'on',
#  'concret',
#  ',',
#  'as',
#  "i'v",
#  'discov',
#  '.',
#  'rt',
#  '@twilightus',
#  'team',
#  'carlisl',
#  'is',
#  'a',
#  'trend',
#  'topic',
#  '-',
#  'help',
#  'him',
#  'out',
#  'rt',
#  'follow',
#  '@peterfacinelli',
#  'see',
#  'a',
#  'grown',
#  'man',
#  'n',
#  'a',
#  'bikini',
#  'danc',
#  'hollywood',
#  'blvd',
#  '@karenrubin',
#  'you',
#  'might',
#  'have',
#  'to',
#  'reinstal',
#  '-',
#  'that',
#  'happen',
#  'to',
#  'me',
#  'a',
#  'few',
#  'month',
#  'ago',
#  ',',
#  'now',
#  'i',
#  'use',
#  'nambu',
#  'on',
#  'my',
#  'mac',
#  'just',
#  'post',
#  ':',
#  'redneck',
#  'dragon',
#  '-',
#  'part',
#  'xxviii',
#  '(',
#  'http://cli.gs/gwy0yt',
#  ')',
#  '"',
#  '"',
#  '"',
#  'paul',
#  'mccartney',
#  '...',
#  'went',
#  'through',
#  'all',
#  'his',
#  'educ',
#  'there',
#  'and',
#  'nobodi',
#  'thought',
#  'he',
#  'had',
#  'ani',
#  'music',
#  'talent',
#  ',',
#  '"',
#  '"',
#  'http://tinyurl.com/nkdbdq',
#  '"',
#  '@ambient',
#  'yeah',
#  ',',
#  'pretti',
#  'much',
#  'how',
#  'i',
#  'feel',
#  'about',
#  'it',
#  '.',
#  '@florianseroussi',
#  'noth',
#  'realli',
#  'notic',
#  '?',
#  'are',
#  'you',
#  'kid',
#  '?',
#  '@toiletooth',
#  'hour',
#  '?',
#  '"',
#  'obama',
#  ',',
#  'hama',
#  ',',
#  'and',
#  'the',
#  'mullah',
#  'be',
#  '"',
#  '"',
#  'helpfu',
#  'l',
#  '"',
#  '"',
#  'http://www.jpost.com/servlet/satellite?cid=1245184848467&pagename=jpost%2fjparticle%2fprint',
#  '"',
#  'rt',
#  '@bbhlab',
#  '81',
#  '%',
#  'of',
#  'twitter',
#  'user',
#  'are',
#  'under',
#  '30',
#  '+',
#  'more',
#  'v',
#  '.',
#  'interest',
#  'statist',
#  'here',
#  ':',
#  'http://www.sysomos.com/insidetwitter/',
#  '@birdingperu',
#  'great',
#  'look',
#  'hummer',
#  '!',
#  'rtthe',
#  'world',
#  'most',
#  'spectacular',
#  'hummingbird',
#  'marvel',
#  'spatuletail',
#  'on',
#  'a',
#  'feeder',
#  '.',
#  'http://bit.ly/aghyz',
#  'attn',
#  '.',
#  'chas',
#  '.',
#  'whitman',
#  ':',
#  'rt',
#  '@villagevoic',
#  'jona',
#  'brother',
#  'at',
#  'rockefel',
#  'center',
#  'for',
#  'the',
#  'today',
#  'show',
#  'tomorrow',
#  'mornâ',
#  '€',
#  '”',
#  'eeeeeeeeee',
#  '!',
#  'aw',
#  'fuck',
#  '!',
#  'it',
#  'turn',
#  'out',
#  'you',
#  "can't",
#  'defend',
#  'the',
#  'champagn',
#  'glass',
#  'hot',
#  'tub',
#  '.',
#  'rt',
#  '@ultimatealek',
#  ':',
#  'my',
#  'life',
#  'has',
#  'been',
#  'fill',
#  'with',
#  'terribl',
#  'misfortun',
#  ';',
#  'most',
#  'of',
#  'which',
#  'never',
#  'happened.montaign',
#  '~',
#  'so',
#  'true',
#  '...',
#  'rt',
#  '@weirdnew',
#  'the',
#  'worldâ',
#  '€',
#  '™',
#  's',
#  'smallest',
#  'whale',
#  'shark',
#  '-',
#  'http://weirdasianews.com?p=4455',
#  'hey',
#  '@aaroncarter7',
#  'chrystina',
#  'and',
#  'cathe',
#  'with',
#  'two',
#  'e',
#  'love',
#  'you',
#  '!',
#  'do',
#  'you',
#  'love',
#  'us',
#  '?',
#  '!',
#  '!',
#  '?',
#  '?',
#  '!',
#  '(',
#  'aaroncartercel',
#  'live',
#  '>',
#  'http://ustre.am/3uyi',
#  ')',
#  '*',
#  'see',
#  'live',
#  'forex',
#  'trade',
#  '-',
#  'anoth',
#  'profit',
#  'trade',
#  'with',
#  'tflow',
#  'student',
#  '...',
#  'http://u.mavrev.com/cflb',
#  '@traevon',
#  "i'm",
#  'put',
#  'your',
#  'song',
#  'on',
#  'the',
#  'podcast',
#  'so',
#  'folk',
#  'can',
#  'check',
#  'you',
#  'out',
#  '.',
#  "i'll",
#  'give',
#  'the',
#  'myspac',
#  'site',
#  'as',
#  'well',
#  '.',
#  'rt',
#  '@melbpubcrawl',
#  ':',
#  'rt',
#  '@tw1sti',
#  ':',
#  'anoth',
#  'random',
#  'thought',
#  ':',
#  '#tw1styiskingofthecastlekingofthebarstool',
#  '#hashtagrebelalli',
#  '#damnwrongaccount',
#  'if',
#  'my',
#  'dog',
#  'should',
#  'go',
#  'blind',
#  'in',
#  'old',
#  'age',
#  ',',
#  'would',
#  'it',
#  'be',
#  'kinder',
#  'to',
#  'have',
#  'him',
#  'put',
#  'to',
#  'sleep',
#  '?',
#  'http://bit.ly/u3fbc',
#  'just',
#  'purchas',
#  '1',
#  'mp',
#  '-',
#  '443',
#  'grach',
#  'http://140mafia.com',
#  '#140mafia',
#  '@mdgonzal',
#  'did',
#  'the',
#  'white',
#  'sox',
#  'ever',
#  'actual',
#  'wear',
#  'these',
#  'unifrom',
#  ',',
#  'are',
#  'are',
#  'they',
#  'just',
#  'throwback-inspir',
#  '?',
#  'rt',
#  '@aieseclima',
#  ':',
#  'aiesec',
#  'lima',
#  '-',
#  'aiesec',
#  'san',
#  'marco',
#  'eb',
#  'gather',
#  'at',
#  'juanjo',
#  '(',
#  'lcp',
#  'lima',
#  ')',
#  'place',
#  '.',
#  'http://bit.ly/ehjsh',
#  'http://bit.ly/jmbqx',
#  'if',
#  'an',
#  'innoc',
#  'girl',
#  'get',
#  'shot',
#  'halfway',
#  'across',
#  'the',
#  'world',
#  ',',
#  'doe',
#  'she',
#  'make',
#  'a',
#  'sound',
#  '?',
#  'yes',
#  'the',
#  'whole',
#  'world',
#  'hear',
#  'her',
#  '&',
#  'will',
#  '#iranelect',
#  '#neda',
#  'rt',
#  'rt',
#  '@crackberrista',
#  ':',
#  'rt',
#  '@johkhz',
#  ':',
#  '@crackberrista',
#  'jejej',
#  ',',
#  'gracia',
#  'por',
#  'el',
#  'rt',
#  '.',
#  'vayan',
#  'pue',
#  'a',
#  'cdlr',
#  '(',
#  'cdr',
#  ',',
#  'hpdlr',
#  ')',
#  'qtpd',
#  ',',
#  'jejej',
#  '#arribaespanol',
#  'bless',
#  'are',
#  'the',
#  'peacemak',
#  ',',
#  'for',
#  'they',
#  'shall',
#  'be',
#  'call',
#  'children',
#  'of',
#  'god',
#  '.',
#  'matthew',
#  '5:9',
#  '#scriptur',
#  '#peac',
#  '#semst',
#  'but',
#  'i',
#  'am',
#  'like',
#  'a',
#  'green',
#  'oliv',
#  'tree',
#  'in',
#  'the',
#  'hous',
#  'of',
#  'god',
#  ';',
#  'i',
#  'will',
#  'trust',
#  'in',
#  'the',
#  'merci',
#  'of',
#  'god',
#  'forev',
#  'and',
#  'ever',
#  '-',
#  'ps',
#  '.',
#  '52:8',
#  '#semst',
#  '@musical_seizur',
#  'it',
#  'veri',
#  'cool',
#  ',',
#  'but',
#  'it',
#  'not',
#  'evid',
#  'for',
#  'ani',
#  '#god',
#  '.',
#  'is',
#  'that',
#  'what',
#  "you'r",
#  'impli',
#  '?',
#  '#semst',
#  'in',
#  '#christ',
#  'we',
#  'are',
#  'righteous',
#  ',',
#  'and',
#  'in',
#  'practic',
#  ',',
#  'we',
#  'are',
#  'be',
#  'conform',
#  'to',
#  'his',
#  'imag',
#  '.',
#  '~',
#  'chip',
#  'ingram',
#  '#quot',
#  '#fb',
#  '#teamjesus',
#  '#semst',
#  'greater',
#  'is',
#  'he',
#  'who',
#  'is',
#  'in',
#  'you',
#  'than',
#  'he',
#  'who',
#  'is',
#  'in',
#  'the',
#  'world',
#  '.',
#  '-',
#  '1john',
#  '4:4',
#  '#god',
#  '#bibl',
#  '#semst',
#  'as',
#  'you',
#  'follow',
#  'me',
#  ',',
#  'i',
#  'lead',
#  'you',
#  'along',
#  'path',
#  'of',
#  'new',
#  ':',
#  'way',
#  'you',
#  'have',
#  'never',
#  'imagin',
#  '.',
#  '-',
#  '@jesus_cal',
#  '#semst',
#  'fill',
#  'your',
#  'church',
#  'with',
#  'holi',
#  'fascin',
#  'for',
#  'the',
#  'man',
#  'christ',
#  'jesus',
#  '.',
#  'he',
#  'is',
#  'what',
#  'we',
#  'need',
#  '.',
#  '#worthi',
#  '#oneth',
#  '#magnific',
#  '#obsess',
#  '#semst',
#  'it',
#  'will',
#  'never',
#  'get',
#  'old',
#  'to',
#  'hear',
#  'when',
#  'christian',
#  'lead',
#  'other',
#  'to',
#  'ultim',
#  'love',
#  '&',
#  'hope',
#  '!',
#  '#discipl',
#  '#share',
#  '#gospel',
#  '#jesuschangeseveryth',
#  '#semst',
#  'religi',
#  'peopl',
#  'are',
#  'peopl',
#  'too',
#  '...',
#  'just',
#  'bigot',
#  ',',
#  'genitalia',
#  'mutil',
#  ',',
#  'angri',
#  'gullibl',
#  'peopl',
#  '#semst',
#  'that',
#  'nag',
#  'doubt',
#  'you',
#  'keep',
#  'have',
#  'about',
#  'god',
#  '?',
#  'god',
#  'not',
#  'test',
#  'u',
#  ',',
#  'it',
#  'your',
#  'intellect',
#  'tri',
#  'to',
#  'tell',
#  'you',
#  'your',
#  'belief',
#  'are',
#  'bullshit',
#  '.',
#  '#semst',
#  'god',
#  'is',
#  'so',
#  'good',
#  '!',
#  'all',
#  'the',
#  'prais',
#  'go',
#  'up',
#  'to',
#  'him',
#  '!',
#  '#semst',
#  '@xfranman',
#  'old',
#  'age',
#  'has',
#  'not',
#  'made',
#  'you',
#  'ani',
#  'wiser',
#  'or',
#  'more',
#  'matur',
#  '.',
#  'for',
#  'shame',
#  '!',
#  '#semst',
#  '@hijabismil',
#  '@nainfidel',
#  '@captains_pick',
#  '@pinchey1964',
#  'both',
#  'are',
#  'utter',
#  'stupid',
#  'and',
#  'useless',
#  'anyway',
#  '.',
#  '#liber',
#  '#democraci',
#  '#semst',
#  'all',
#  'we',
#  'need',
#  'is',
#  'to',
#  'go',
#  'back',
#  'to',
#  'our',
#  'root',
#  'and',
#  'get',
#  'closer',
#  'to',
#  'natur',
#  '.',
#  '#simplelif',
#  '#liveeasi',
#  '#foodforal',
#  '#goslow',
#  '#semst',
#  "'",
#  'pop',
#  'may',
#  'throw',
#  'in',
#  'the',
#  'towel',
#  'second',
#  'half',
#  '..',
#  '#semst']

# %%
lemmatize("\n".join(data))
# Out:
# ['@anitapuspasari',
#  'waduh',
#  '..',
#  '\n\n',
#  '"',
#  'could',
#  'journos',
#  'please',
#  'stop',
#  'put',
#  'the',
#  'word',
#  '"',
#  '"',
#  'gate',
#  '"',
#  '"',
#  'after',
#  'everything',
#  'they',
#  'write',
#  '...',
#  'gate',
#  '.',
#  '"',
#  '\n\n',
#  '20',
#  '%',
#  'More',
#  'Ridiculous',
#  'Sale',
#  '@20x200',
#  'end',
#  'tonight',
#  '!',
#  '-',
#  'get',
#  '20',
#  '%',
#  'off',
#  'by',
#  'enter',
#  "'",
#  'ridonk',
#  "'",
#  'at',
#  'checkout',
#  '.',
#  'More',
#  'info',
#  ':',
#  'http://bit.ly/ridonktue',
#  '\n\n',
#  '@studio85',
#  'I',
#  'have',
#  'a',
#  'pair',
#  'of',
#  'those',
#  'shoe',
#  '.',
#  'they',
#  'be',
#  'comfy',
#  '.',
#  'like',
#  'be',
#  'barefoot',
#  '.',
#  'okay',
#  'for',
#  'run',
#  ',',
#  'but',
#  'not',
#  'on',
#  'concrete',
#  ',',
#  'as',
#  'I',
#  "'ve",
#  'discover',
#  '.',
#  '\n\n',
#  'RT',
#  '@twilightus',
#  'Team',
#  'Carlisle',
#  'be',
#  'a',
#  'trending',
#  'topic-',
#  'help',
#  'he',
#  'out',
#  'RT',
#  'Follow',
#  '@peterfacinelli',
#  'see',
#  'a',
#  'grown',
#  'man',
#  'n',
#  'a',
#  'bikini',
#  'dance',
#  'Hollywood',
#  'Blvd',
#  '\n\n',
#  '@karenrubin',
#  'you',
#  'might',
#  'have',
#  'to',
#  'reinstall',
#  '-',
#  'that',
#  'happen',
#  'to',
#  'I',
#  'a',
#  'few',
#  'month',
#  'ago',
#  ',',
#  'now',
#  'I',
#  'use',
#  'Nambu',
#  'on',
#  'my',
#  'Mac',
#  '\n\n',
#  'just',
#  'post',
#  ':',
#  'Redneck',
#  'Dragon',
#  '-',
#  'Part',
#  'XXVIII',
#  '(',
#  'http://cli.gs/gWy0yT',
#  ')',
#  '\n\n',
#  '"',
#  '"',
#  '"',
#  'Paul',
#  'McCartney',
#  '...',
#  'go',
#  'through',
#  'all',
#  'his',
#  'education',
#  'there',
#  'and',
#  'nobody',
#  'think',
#  'he',
#  'have',
#  'any',
#  'musical',
#  'talent',
#  ',',
#  '"',
#  '"',
#  'http://tinyurl.com/nkdbdq',
#  '"',
#  '\n\n',
#  '@ambienteer',
#  'Yeah',
#  ',',
#  'pretty',
#  'much',
#  'how',
#  'I',
#  'feel',
#  'about',
#  'it',
#  '.',
#  '\n\n',
#  '@florianseroussi',
#  'Nothing',
#  'really',
#  'noticeable',
#  '?',
#  'be',
#  'you',
#  'kid',
#  '?',
#  '\n\n',
#  '@toiletooth',
#  'Hours',
#  '?',
#  '\n\n',
#  '"',
#  'Obama',
#  ',',
#  'Hamas',
#  ',',
#  'and',
#  'the',
#  'Mullahs',
#  'be',
#  '"',
#  '"',
#  'helpfu',
#  'l""http://www.jpost.com',
#  '/',
#  'servlet',
#  '/',
#  'Satellite?cid=1245184848467&pagename',
#  '=',
#  'JPost%2FJPArticle%2FPrinter',
#  '"',
#  '\n\n',
#  'RT',
#  '@BBHLabs',
#  '81',
#  '%',
#  'of',
#  'twitter',
#  'user',
#  'be',
#  'under',
#  '30',
#  '+',
#  'more',
#  'v.',
#  'interesting',
#  'statistic',
#  'here',
#  ':',
#  'http://www.sysomos.com/insidetwitter/',
#  '\n\n',
#  '@Birdingperu',
#  'great',
#  'look',
#  'hummer',
#  '!',
#  'RTThe',
#  'world',
#  "'s",
#  'most',
#  'spectacular',
#  'hummingbird',
#  'Marvelous',
#  'Spatuletail',
#  'on',
#  'a',
#  'feeder',
#  '.',
#  'http://bit.ly/aghyz',
#  '\n\n',
#  'attn',
#  '.',
#  'chas',
#  '.',
#  'whitman',
#  ':',
#  'RT',
#  '@villagevoice',
#  'Jonas',
#  'Brothers',
#  'at',
#  'Rockefeller',
#  'Center',
#  'for',
#  'the',
#  'Today',
#  'Show',
#  'tomorrow',
#  'mornâ€”EEEEEEEEEE',
#  '!',
#  '\n\n',
#  'aw',
#  'fuck',
#  '!',
#  'it',
#  'turn',
#  'out',
#  'you',
#  'can',
#  'not',
#  'defend',
#  'the',
#  'champagne',
#  'glass',
#  'hot',
#  'tub',
#  '.',
#  '\n\n',
#  'RT',
#  '@ultimatealek',
#  ':',
#  'my',
#  'life',
#  'have',
#  'be',
#  'fill',
#  'with',
#  'terrible',
#  'misfortune',
#  ';',
#  'most',
#  'of',
#  'which',
#  'never',
#  'happen',
#  '.',
#  'Montaigne',
#  '~',
#  'so',
#  'true',
#  '...',
#  '\n\n',
#  'RT',
#  '@weirdnews',
#  'the',
#  'Worldâ€',
#  '™',
#  's',
#  'Smallest',
#  'Whale',
#  'Shark',
#  '-',
#  'http://weirdasianews.com?p=4455',
#  '\n\n',
#  'hey',
#  '@aaroncarter7',
#  'chrystina',
#  'and',
#  'cathee',
#  'with',
#  'two',
#  'e',
#  "'s",
#  'love',
#  'you',
#  '!',
#  'do',
#  'you',
#  'love',
#  'we',
#  '?',
#  '!',
#  '!',
#  '?',
#  '?',
#  '!',
#  '(',
#  'AARONCARTERCELL',
#  'live',
#  '>',
#  'http://ustre.am/3uyi',
#  ')',
#  '\n\n',
#  '*',
#  'see',
#  '\n\n',
#  'live',
#  'forex',
#  'trading',
#  '-',
#  'another',
#  'profitable',
#  'trade',
#  'with',
#  'tflow',
#  'student',
#  '...',
#  'http://u.mavrev.com/cflb',
#  '\n\n',
#  '@TRAEvon',
#  'I',
#  'be',
#  'put',
#  'your',
#  'song',
#  'on',
#  'the',
#  'podcast',
#  'so',
#  'folk',
#  'can',
#  'check',
#  'you',
#  'out',
#  '.',
#  'I',
#  'will',
#  'give',
#  'the',
#  'myspace',
#  'site',
#  'as',
#  'well',
#  '.',
#  '\n\n',
#  'RT',
#  '@melbpubcrawl',
#  ':',
#  'RT',
#  '@Tw1sty',
#  ':',
#  'another',
#  'random',
#  'thought',
#  ':',
#  '#',
#  'tw1styiskingofthecastlekingofthebarstool',
#  '#',
#  'hashtagrebelalliance',
#  '#',
#  'damnwrongaccount',
#  '\n\n',
#  'if',
#  'my',
#  'dog',
#  'should',
#  'go',
#  'blind',
#  'in',
#  'old',
#  'age',
#  ',',
#  'would',
#  'it',
#  'be',
#  'kind',
#  'to',
#  'have',
#  'he',
#  'put',
#  'to',
#  'sleep',
#  '?',
#  'http://bit.ly/u3fbc',
#  '\n\n',
#  'just',
#  'purchase',
#  '1',
#  'MP-443',
#  'Grach',
#  'http://140mafia.com',
#  '#',
#  '140mafia',
#  '\n\n',
#  '@mdgonzale',
#  'do',
#  'the',
#  'White',
#  'Sox',
#  'ever',
#  'actually',
#  'wear',
#  'these',
#  'unifrom',
#  ',',
#  'be',
#  'be',
#  'they',
#  'just',
#  'throwback',
#  '-',
#  'inspire',
#  '?',
#  '\n\n',
#  'RT',
#  '@AIESECLima',
#  ':',
#  'AIESEC',
#  'Lima',
#  '-',
#  'AIESEC',
#  'San',
#  'Marcos',
#  'EB',
#  'gather',
#  'at',
#  'Juanjo',
#  "'s",
#  '(',
#  'LCP',
#  'Lima',
#  ')',
#  'place',
#  '.',
#  'http://bit.ly/eHJsH',
#  'http://bit.ly/jMBqX',
#  '\n\n',
#  'if',
#  'an',
#  'innocent',
#  'girl',
#  'gets',
#  'shoot',
#  'halfway',
#  'across',
#  'the',
#  'world',
#  ',',
#  'do',
#  'she',
#  'make',
#  'a',
#  'sound',
#  '?',
#  'yes',
#  'the',
#  'whole',
#  'world',
#  'hear',
#  'she',
#  '&',
#  'will',
#  '#',
#  'iranelection',
#  '#',
#  'neda',
#  'RT',
#  '\n\n',
#  'RT',
#  '@crackberrista',
#  ':',
#  'RT',
#  '@johkhz',
#  ':',
#  '@crackberrista',
#  'jejeje',
#  ',',
#  'gracias',
#  'por',
#  'el',
#  'RT',
#  '.',
#  'Vayan',
#  'pue',
#  'a',
#  'CDLR',
#  '(',
#  'CDR',
#  ',',
#  'HPDLR',
#  ')',
#  'QTPD',
#  ',',
#  'jejeje',
#  '#',
#  'arribaespanol',
#  '\n\n',
#  'Blessed',
#  'be',
#  'the',
#  'peacemaker',
#  ',',
#  'for',
#  'they',
#  'shall',
#  'be',
#  'call',
#  'child',
#  'of',
#  'God',
#  '.',
#  'Matthew',
#  '5:9',
#  '#',
#  'scripture',
#  '#',
#  'peace',
#  '#',
#  'semst',
#  '\n\n',
#  'but',
#  'I',
#  'be',
#  'like',
#  'a',
#  'green',
#  'olive',
#  'tree',
#  'in',
#  'the',
#  'house',
#  'of',
#  'God',
#  ';',
#  'I',
#  'will',
#  'trust',
#  'in',
#  'the',
#  'mercy',
#  'of',
#  'God',
#  'forever',
#  'and',
#  'ever',
#  '-Ps',
#  '.',
#  '52:8',
#  '#',
#  'SemST',
#  '\n\n',
#  '@musical_seizure',
#  ' ',
#  'it',
#  'be',
#  'very',
#  'cool',
#  ',',
#  'but',
#  'it',
#  'be',
#  'not',
#  'evidence',
#  'for',
#  'any',
#  '#',
#  'god',
#  '.',
#  'be',
#  'that',
#  'what',
#  'you',
#  'be',
#  'imply',
#  '?',
#  ' ',
#  '#',
#  'SemST',
#  '\n\n',
#  'in',
#  '#',
#  'Christ',
#  'we',
#  'be',
#  'righteous',
#  ',',
#  'and',
#  'in',
#  'practice',
#  ',',
#  'we',
#  'be',
#  'be',
#  'conform',
#  'to',
#  'his',
#  'image.~',
#  'Chip',
#  'Ingram',
#  '#',
#  'quote',
#  '#',
#  'FB',
#  '#',
#  'TeamJesus',
#  '#',
#  'semst',
#  '\n\n',
#  'Greater',
#  'be',
#  'he',
#  'who',
#  'be',
#  'in',
#  'you',
#  'than',
#  'he',
#  'who',
#  'be',
#  'in',
#  'the',
#  'world',
#  '.',
#  '-',
#  '1John',
#  '4:4',
#  '#',
#  'god',
#  '#',
#  'bible',
#  '#',
#  'SemST',
#  '\n\n',
#  'as',
#  'you',
#  'follow',
#  'I',
#  ',',
#  'I',
#  'lead',
#  'you',
#  'along',
#  'path',
#  'of',
#  'newness',
#  ':',
#  'way',
#  'you',
#  'have',
#  'never',
#  'imagine',
#  '.',
#  '-',
#  '@jesus_calle',
#  ' ',
#  '#',
#  'semst',
#  '\n\n',
#  'fill',
#  'your',
#  'church',
#  'with',
#  'holy',
#  'fascination',
#  'for',
#  'the',
#  'man',
#  'Christ',
#  'Jesus',
#  '.',
#  'he',
#  'be',
#  'what',
#  'we',
#  'need',
#  '.',
#  '#',
#  'worthy',
#  '#',
#  'onethe',
#  '#',
#  'magnificent',
#  '#',
#  'obsession',
#  '#',
#  'semst',
#  '\n\n',
#  'it',
#  'will',
#  'never',
#  'get',
#  'old',
#  'to',
#  'hear',
#  'when',
#  'christian',
#  'lead',
#  'other',
#  'to',
#  'ultimate',
#  'love',
#  '&',
#  'hope',
#  '!',
#  '#',
#  'disciple',
#  '#',
#  'share',
#  '#',
#  'gospel',
#  '#',
#  'JesusChangesEverything',
#  '#',
#  'semst',
#  '\n\n',
#  'religious',
#  'people',
#  'be',
#  'people',
#  'too',
#  '......',
#  'just',
#  'bigote',
#  ',',
#  'genitalia',
#  'mutilating',
#  ',',
#  'angry',
#  'gullible',
#  'people',
#  '#',
#  'semst',
#  '\n\n',
#  'that',
#  'nagging',
#  'doubt',
#  'you',
#  'keep',
#  'have',
#  'about',
#  'god',
#  '?',
#  'god',
#  'not',
#  'test',
#  'u',
#  ',',
#  'it',
#  'be',
#  'your',
#  'intellect',
#  'try',
#  'to',
#  'tell',
#  'you',
#  'your',
#  'belief',
#  'be',
#  'bullshit',
#  '.',
#  '#',
#  'semst',
#  '\n\n',
#  'God',
#  'be',
#  'so',
#  'good',
#  '!',
#  'all',
#  'the',
#  'praise',
#  'go',
#  'up',
#  'to',
#  'he',
#  '!',
#  '#',
#  'semst',
#  '\n\n',
#  '@xfranman',
#  'Old',
#  'age',
#  'have',
#  'not',
#  'make',
#  'you',
#  'any',
#  'wise',
#  'or',
#  'more',
#  'mature',
#  '.',
#  'for',
#  'shame',
#  '!',
#  '#',
#  'SemST',
#  '\n\n',
#  '@HijabiSmile',
#  '@NAInfidels',
#  '@captains_pick',
#  '@pinchey1964',
#  'both',
#  'be',
#  'utterly',
#  'stupid',
#  'and',
#  'useless',
#  'anyway',
#  '.',
#  '#',
#  'liberalism',
#  '#',
#  'democracy',
#  '#',
#  'semst',
#  '\n\n',
#  'all',
#  'we',
#  'need',
#  'be',
#  'to',
#  'go',
#  'back',
#  'to',
#  'our',
#  'root',
#  'and',
#  'get',
#  'close',
#  'to',
#  'nature',
#  '.',
#  ' ',
#  '#',
#  'simplelife',
#  '#',
#  'liveeasy',
#  '#',
#  'foodforall',
#  '#',
#  'goslow',
#  '#',
#  'semst',
#  '\n\n',
#  "'",
#  'pop',
#  'may',
#  'throw',
#  'in',
#  'the',
#  'towel',
#  'second',
#  'half',
#  '..',
#  '#',
#  'semst',
#  '\n']

# %% [markdown]
# ## Explain sentencepiece (for masters only)
#
# For this task you will have to use sentencepiece text tokenizer. Your task will be to read how it works and write a minimum 10 sentences explanation of the tokenizer works.

# %% [markdown]
# ...

# %% [markdown]
# ## Resources
#
# 1. [Regular Expressions 1](https://realpython.com/regex-python/)
# 2. [Regular Expressions 2](https://realpython.com/regex-python-part-2/)
# 2. [Spacy Lemmatizer](https://spacy.io/api/lemmatizer)
# 2. [NLTK Stem](https://www.nltk.org/howto/stem.html)
# 3. [SentencePiece](https://github.com/google/sentencepiece)
# 4. [sentencepiece tokenizer](https://towardsdatascience.com/sentencepiece-tokenizer-demystified-d0a3aac19b15)
