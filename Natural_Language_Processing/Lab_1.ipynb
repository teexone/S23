# %% [markdown]
# # Natural Language Processing. Lab 1
# Professor: Vladimir Ivanov
#
# Teaching Assistant: Aidar Valeev

# %% [markdown]
# ## Task 1
# Write a python program that does the following :
# 1. retrieve content of a wikipedia page on a topic of your choice - english
# 2. retrieve content of a wikipedia page on a topic of your choice - language of your choice (i.e russian, french)
# 3. preprocess the data
# 4. print distinct words statatistics, number of chapters, number of sentences, numerical values, number of entities with links

# %%
import wikipedia
import requests
import re
from nltk.tokenize import sent_tokenize, word_tokenize, RegexpTokenizer

from collections import defaultdict

# %%
ru_link = "https://ru.wikipedia.org/wiki/Университет_Иннополис"
en_link = "https://en.wikipedia.org/wiki/Innopolis_University"

# %%
def get_num_values(text):
    return len(re.findall(r"[0-9]+", text))

def words(text):
    tokenizer = RegexpTokenizer(r"\w+")
    return tokenizer.tokenize(text)

def sentences(text):
    return sent_tokenize(text)

def count_words(tokenized_text):
    counter = defaultdict(lambda: 0)
    for word in tokenized_text:
        counter[word] += 1
    return counter

# %%
en_content = wikipedia.page("Innopolis_University")
wikipedia.set_lang("ru")
ru_content = wikipedia.page("Университет_Иннополис")

# %%
# Out:
# ['== История ==',
#  '== Проектная и научная деятельность ==',
#  '== Учебные программы ==',
#  '== Особенности обучения ==',
#  '== Руководство ==',
#  '== Наблюдательный совет университета ==',
#  '== Профессорско-преподавательский состав ==',
#  '== Численность студентов ==',
#  '== Структура университета ==',
#  '== Кампус университета ==',
#  '== Финансирование университета ==',
#  '== Сотрудничество университета ==',
#  '== Рейтинги ==',
#  '== Примечания ==',
#  '== Источники ==']

# %%
import json

metrics = {
    "ru": {
        "links": len(ru_content.links), 
        "words": len(words(ru_content.content)),
        "sentences": len(sentences(ru_content.content)),
        "numericals": get_num_values(ru_content.content),
        "chapters": len(re.findall(r"==.*==", ru_content.content))
    },
    "en": {
        "links": len(en_content.links), 
        "words": len(words(en_content.content)),
        "sentences": len(sentences(en_content.content)),
        "numericals": get_num_values(en_content.content),
        "chapters": len(re.findall(r"==.*==", en_content.content))
    }
}

print(json.dumps(metrics, indent=2, default=str))

print(f"For russian text: {json.dumps(count_words(words(en_content.content)), indent=2, default=str, ensure_ascii=False)}\n\n")
print(f"For english text: {json.dumps(count_words(words(ru_content.content)), indent=2, default=str, ensure_ascii=False)}\n\n")
# Out:
# {
#   "ru": {
#     "links": 351,
#     "words": 3117,
#     "sentences": 151,
#     "numericals": 212,
#     "chapters": 28
#   },
#   "en": {
#     "links": 71,
#     "words": 3066,
#     "sentences": 169,
#     "numericals": 201,
#     "chapters": 15
#   }
# }
# For russian text: {
#   "Университет": 18,
#   "Иннополис": 44,
#   "тат": 1,
#   "университеты": 1,
#   "автономияле": 1,
#   "коммерцияле": 1,
#   "булмаган": 1,
#   "югары": 1,
#   "белем": 1,
#   "бирү": 1,
#   "оешмасы": 1,
#   "российская": 1,
#   "автономная": 1,
#   "некоммерческая": 1,
#   "организация": 1,
#   "высшего": 5,
#   "образования": 9,
#   "в": 107,
#   "городе": 5,
#   "Верхнеуслонский": 1,
#   "район": 1,
#   "Республика": 3,
#   "Татарстан": 9,
#   "специализирующаяся": 1,
#   "на": 41,
#   "образовании": 2,
#   "исследованиях": 1,
#   "и": 134,
#   "разработках": 1,
#   "области": 11,
#   "информационных": 6,
#   "технологий": 21,
#   "робототехники": 11,
#   "Первоначально": 1,
#   "университет": 3,
#   "действовал": 1,
#   "Казань": 1,
#   "с": 21,
#   "сентября": 2,
#   "2015": 9,
#   "года": 31,
#   "открыт": 1,
#   "кампус": 2,
#   "университета": 21,
#   "В": 49,
#   "Университете": 5,
#   "обучают": 1,
#   "разработчиков": 1,
#   "управленцев": 1,
#   "высоких": 1,
#   "проводят": 1,
#   "научные": 2,
#   "исследования": 3,
#   "сферах": 1,
#   "Вуз": 1,
#   "зарегистрирован": 1,
#   "10": 5,
#   "декабря": 4,
#   "2012": 6,
#   "Учредители": 1,
#   "Российская": 1,
#   "Федерация": 1,
#   "лице": 2,
#   "Министерства": 5,
#   "цифрового": 3,
#   "развития": 10,
#   "связи": 5,
#   "массовых": 3,
#   "коммуникаций": 3,
#   "Российской": 2,
#   "Федерации": 2,
#   "земельных": 1,
#   "имущественных": 1,
#   "отношений": 1,
#   "РТ": 2,
#   "История": 1,
#   "О": 2,
#   "создании": 2,
#   "Университета": 20,
#   "объявили": 1,
#   "феврале": 2,
#   "переговорах": 1,
#   "Университетом": 4,
#   "Карнеги": 4,
#   "Меллона": 3,
#   "по": 29,
#   "созданию": 2,
#   "Татарстане": 1,
#   "центра": 8,
#   "подготовки": 2,
#   "ИТ": 9,
#   "кадров": 2,
#   "выпускающего": 1,
#   "1": 15,
#   "000": 6,
#   "специалистов": 5,
#   "год": 6,
#   "июле": 1,
#   "президент": 2,
#   "Республики": 5,
#   "Рустам": 2,
#   "Минниханов": 2,
#   "встретился": 1,
#   "Гилом": 1,
#   "Тараном": 1,
#   "руководителем": 1,
#   "дочерней": 1,
#   "структуры": 1,
#   "Carnegie": 2,
#   "Mellon": 2,
#   "University": 2,
#   "iCarnegie": 2,
#   "Global": 1,
#   "Learning": 1,
#   "которая": 1,
#   "занимается": 2,
#   "развитием": 3,
#   "популяризацией": 1,
#   "а": 3,
#   "также": 2,
#   "продажей": 1,
#   "лицензий": 1,
#   "образовательные": 1,
#   "программы": 10,
#   "Тогда": 1,
#   "стороны": 1,
#   "договорились": 1,
#   "о": 8,
#   "нового": 2,
#   "территории": 3,
#   "Иннополиса": 1,
#   "Административным": 1,
#   "директором": 1,
#   "вуза": 3,
#   "назначен": 1,
#   "кандидат": 1,
#   "физико": 4,
#   "математических": 3,
#   "наук": 4,
#   "предприниматель": 1,
#   "учредитель": 1,
#   "сети": 2,
#   "образовательных": 3,
#   "центров": 4,
#   "для": 27,
#   "школьников": 1,
#   "Юниум": 1,
#   "Дмитрий": 3,
#   "Кондратьев": 1,
#   "ректором": 1,
#   "доктор": 2,
#   "профессор": 2,
#   "Александр": 3,
#   "Тормасов": 2,
#   "прошла": 2,
#   "первичная": 1,
#   "юридическая": 1,
#   "регистрация": 1,
#   "качестве": 2,
#   "Автономной": 1,
#   "некоммерческой": 1,
#   "организации": 1,
#   "21": 1,
#   "АНО": 2,
#   "ВО": 2,
#   "подписали": 1,
#   "меморандум": 1,
#   "согласии": 1,
#   "частности": 1,
#   "специалисты": 4,
#   "подразделения": 1,
#   "изучили": 1,
#   "российскую": 1,
#   "индустрию": 1,
#   "качество": 1,
#   "Результаты": 2,
#   "позже": 1,
#   "использовались": 1,
#   "разработки": 7,
#   "образовательной": 1,
#   "концепции": 1,
#   "Также": 4,
#   "американского": 1,
#   "были": 3,
#   "привлечены": 1,
#   "к": 2,
#   "разработке": 2,
#   "инфраструктуры": 4,
#   "учебных": 1,
#   "программ": 5,
#   "тот": 2,
#   "же": 3,
#   "началось": 2,
#   "строительство": 4,
#   "кампуса": 1,
#   "Иннополисе": 2,
#   "апреле": 1,
#   "2013": 9,
#   "объявил": 3,
#   "конкурсном": 1,
#   "наборе": 2,
#   "преподавателей": 4,
#   "сотрудников": 2,
#   "На": 3,
#   "15": 3,
#   "мест": 4,
#   "поступило": 1,
#   "700": 1,
#   "заявок": 2,
#   "но": 2,
#   "годовое": 1,
#   "обучение": 5,
#   "программе": 4,
#   "Software": 1,
#   "Engineering": 2,
#   "уехали": 1,
#   "14": 4,
#   "человек": 4,
#   "Казани": 3,
#   "состоялось": 1,
#   "открытие": 1,
#   "первых": 1,
#   "STEM": 1,
#   "Science": 1,
#   "Technology": 1,
#   "Mathematics": 1,
#   "которых": 4,
#   "школьники": 1,
#   "6": 4,
#   "11": 2,
#   "классов": 1,
#   "обучались": 2,
#   "робототехнике": 2,
#   "математике": 1,
#   "физике": 1,
#   "программированию": 1,
#   "английскому": 1,
#   "языку": 1,
#   "50": 3,
#   "слушателей": 1,
#   "лучшими": 1,
#   "результатами": 1,
#   "итогам": 3,
#   "тестирования": 2,
#   "бесплатно": 1,
#   "9": 2,
#   "первом": 1,
#   "помещении": 1,
#   "совместная": 1,
#   "МФТИ": 2,
#   "Школа": 1,
#   "высокопроизводительным": 1,
#   "вычислениям": 1,
#   "декабре": 4,
#   "стал": 3,
#   "федеральной": 1,
#   "инновационной": 1,
#   "площадкой": 2,
#   "Победители": 1,
#   "получили": 1,
#   "приоритетную": 1,
#   "поддержку": 1,
#   "создания": 2,
#   "прорывных": 2,
#   "исследований": 3,
#   "январе": 3,
#   "2014": 6,
#   "согласно": 1,
#   "распоряжению": 1,
#   "Правительства": 1,
#   "от": 5,
#   "30": 4,
#   "г": 2,
#   "N": 1,
#   "2602": 1,
#   "р": 1,
#   "рамках": 10,
#   "плана": 1,
#   "мероприятий": 1,
#   "дорожной": 2,
#   "карты": 2,
#   "Развитие": 1,
#   "отрасли": 3,
#   "пилотной": 1,
#   "современных": 1,
#   "сфере": 2,
#   "обучения": 10,
#   "привлечением": 1,
#   "их": 2,
#   "исследованиям": 1,
#   "разработкам": 1,
#   "конце": 1,
#   "премьер": 2,
#   "министр": 3,
#   "России": 8,
#   "Медведев": 1,
#   "утвердил": 1,
#   "вуз": 6,
#   "бакалавров": 1,
#   "кандидатов": 1,
#   "рассматривались": 1,
#   "студенты": 2,
#   "3": 4,
#   "5": 2,
#   "курсов": 1,
#   "российских": 3,
#   "зарубежных": 2,
#   "университетов": 1,
#   "Планировалось": 1,
#   "набрать": 1,
#   "40": 1,
#   "студентов": 11,
#   "лишь": 1,
#   "26": 2,
#   "человека": 1,
#   "прошли": 2,
#   "конкурсный": 1,
#   "отбор": 1,
#   "хотя": 1,
#   "получил": 5,
#   "300": 1,
#   "Они": 1,
#   "начали": 2,
#   "летом": 1,
#   "того": 2,
#   "казанской": 1,
#   "площадке": 1,
#   "статус": 2,
#   "оператора": 1,
#   "Российского": 1,
#   "этапа": 1,
#   "Всемирной": 1,
#   "олимпиады": 3,
#   "роботов": 1,
#   "WRO": 1,
#   "World": 1,
#   "Robot": 1,
#   "Olympiad": 1,
#   "июне": 3,
#   "базе": 9,
#   "Академии": 1,
#   "Тенниса": 1,
#   "прошёл": 1,
#   "российский": 2,
#   "этап": 2,
#   "С": 4,
#   "проходит": 2,
#   "августе": 1,
#   "лицензию": 1,
#   "аспирантуры": 4,
#   "конференция": 1,
#   "Цифровая": 2,
#   "индустрия": 1,
#   "промышленности": 1,
#   "ЦИПР": 1,
#   "инициированная": 1,
#   "госкорпорацией": 1,
#   "Ростех": 1,
#   "мае": 2,
#   "заключил": 2,
#   "соглашение": 1,
#   "сотрудничестве": 1,
#   "ЦЕРН": 1,
#   "К": 3,
#   "открытию": 1,
#   "города": 1,
#   "соглашения": 1,
#   "подготовке": 1,
#   "проведении": 1,
#   "научно": 4,
#   "исследовательских": 1,
#   "опытно": 1,
#   "конструкторских": 1,
#   "работ": 2,
#   "обороны": 1,
#   "компаний": 4,
#   "Энвижн": 2,
#   "Груп": 2,
#   "Mail": 2,
#   "Ru": 2,
#   "Group": 3,
#   "концерна": 2,
#   "Радиотехнические": 2,
#   "Информационные": 2,
#   "системы": 8,
#   "течение": 1,
#   "отборов": 1,
#   "проходивших": 1,
#   "мая": 2,
#   "июль": 1,
#   "было": 2,
#   "принято": 1,
#   "более": 2,
#   "350": 1,
#   "из": 9,
#   "45": 1,
#   "областей": 2,
#   "странВ": 1,
#   "сентябре": 1,
#   "зданиях": 1,
#   "октября": 1,
#   "Дмитрия": 1,
#   "Кондратьева": 1,
#   "посту": 1,
#   "директора": 1,
#   "сменил": 1,
#   "региональный": 1,
#   "руководитель": 6,
#   "член": 1,
#   "совета": 3,
#   "директоров": 2,
#   "Microsoft": 1,
#   "Кирилл": 2,
#   "Семенихин": 3,
#   "2016": 3,
#   "году": 32,
#   "университете": 3,
#   "открылся": 3,
#   "Центр": 12,
#   "информационной": 5,
#   "безопасности": 6,
#   "сотрудники": 1,
#   "которого": 4,
#   "разрабатывают": 2,
#   "раннего": 1,
#   "предупреждения": 1,
#   "компьютерном": 1,
#   "нападении": 1,
#   "критическую": 1,
#   "инфраструктуру": 2,
#   "предприятий": 1,
#   "2017": 2,
#   "выигрыше": 1,
#   "грантового": 1,
#   "конкурса": 1,
#   "создание": 2,
#   "развитие": 2,
#   "Центра": 1,
#   "компетенций": 5,
#   "НТИ": 4,
#   "направлению": 5,
#   "Технологии": 4,
#   "компонентов": 4,
#   "мехатроники": 4,
#   "2018": 4,
#   "официально": 2,
#   "центре": 2,
#   "работают": 4,
#   "8": 2,
#   "лабораторий": 2,
#   "которые": 3,
#   "занимаются": 3,
#   "изучением": 2,
#   "разработками": 3,
#   "антропоморфной": 2,
#   "промышленной": 3,
#   "беспилотного": 2,
#   "транспорта": 3,
#   "летательных": 3,
#   "средств": 7,
#   "нейронауки": 3,
#   "искусственного": 9,
#   "интеллекта": 9,
#   "др": 2,
#   "консорциум": 2,
#   "входят": 3,
#   "156": 2,
#   "партнеров": 1,
#   "ведущие": 3,
#   "вузы": 3,
#   "академические": 2,
#   "институты": 2,
#   "страны": 2,
#   "крупные": 1,
#   "индустриальные": 2,
#   "предприятия": 1,
#   "зарубежные": 1,
#   "партнёры": 2,
#   "Ключевые": 2,
#   "них": 2,
#   "СберБанк": 1,
#   "Аэрофлот": 4,
#   "РЖД": 2,
#   "Газпром": 3,
#   "нефть": 1,
#   "РУСАЛ": 2,
#   "КАМАЗ": 3,
#   "ИТМО": 3,
#   "ДВФУ": 2,
#   "ВолгГТУ": 1,
#   "ИжГТУ": 2,
#   "2019": 3,
#   "вместе": 1,
#   "членами": 1,
#   "консорциума": 2,
#   "презентовали": 1,
#   "дорожную": 1,
#   "карту": 1,
#   "сенсорики": 1,
#   "до": 3,
#   "2024": 2,
#   "25": 3,
#   "55": 1,
#   "программам": 6,
#   "дополнительного": 1,
#   "2021": 10,
#   "реализации": 2,
#   "федеральных": 1,
#   "проектов": 4,
#   "Кадры": 1,
#   "цифровой": 5,
#   "экономики": 6,
#   "Демография": 1,
#   "программах": 1,
#   "CDO": 2,
#   "Методы": 1,
#   "технологии": 3,
#   "основанные": 1,
#   "работе": 1,
#   "данными": 2,
#   "Управление": 3,
#   "основанное": 1,
#   "данных": 9,
#   "обучились": 1,
#   "16": 1,
#   "госслужащих": 1,
#   "2020": 7,
#   "лидирующего": 1,
#   "исследовательского": 1,
#   "блокчейна": 1,
#   "выиграв": 1,
#   "конкурсе": 1,
#   "РФ": 8,
#   "Специалисты": 3,
#   "создали": 2,
#   "первую": 1,
#   "мире": 3,
#   "полностью": 2,
#   "верифицированную": 1,
#   "блокчейн": 4,
#   "платформу": 1,
#   "Партнёр": 1,
#   "проекта": 3,
#   "создана": 1,
#   "единая": 1,
#   "площадка": 1,
#   "повышения": 2,
#   "квалификации": 1,
#   "среднего": 1,
#   "профессионального": 1,
#   "Опорный": 1,
#   "образовательный": 1,
#   "центр": 6,
#   "ООЦ": 1,
#   "Единый": 1,
#   "учебно": 4,
#   "методологический": 1,
#   "ЕМЦ": 1,
#   "формированием": 1,
#   "цифровых": 2,
#   "методистов": 1,
#   "вузов": 4,
#   "ссузов": 1,
#   "готовящих": 1,
#   "приоритетным": 1,
#   "отраслям": 1,
#   "должен": 1,
#   "обучить": 1,
#   "80": 1,
#   "тысяч": 1,
#   "что": 1,
#   "составляет": 1,
#   "общей": 1,
#   "численности": 1,
#   "профессорско": 1,
#   "преподавательского": 1,
#   "состава": 1,
#   "средне": 1,
#   "профессиональном": 1,
#   "высшем": 1,
#   "создал": 1,
#   "первый": 3,
#   "Институт": 10,
#   "объединил": 1,
#   "действующие": 1,
#   "лаборатории": 6,
#   "имеющиеся": 1,
#   "Проектная": 1,
#   "научная": 2,
#   "деятельность": 2,
#   "балансе": 1,
#   "находятся": 1,
#   "360": 1,
#   "результатов": 1,
#   "интеллектуальной": 1,
#   "деятельности": 4,
#   "170": 1,
#   "РИД": 2,
#   "большая": 1,
#   "часть": 1,
#   "коммерциализируется": 1,
#   "благодаря": 1,
#   "оформлению": 1,
#   "лицензионных": 1,
#   "соглашений": 1,
#   "доход": 1,
#   "достиг": 1,
#   "150": 1,
#   "млн": 5,
#   "рублей": 8,
#   "Для": 1,
#   "дальнейшего": 1,
#   "этих": 1,
#   "показателей": 1,
#   "был": 1,
#   "создан": 2,
#   "Межотраслевой": 2,
#   "трансфера": 3,
#   "помогающий": 1,
#   "учёным": 1,
#   "коммерциализировать": 1,
#   "продвигать": 1,
#   "результаты": 1,
#   "разработок": 1,
#   "создаёт": 1,
#   "среду": 1,
#   "усиления": 1,
#   "сотрудничества": 1,
#   "коммерциализации": 2,
#   "между": 1,
#   "организациями": 1,
#   "науки": 2,
#   "стартапами": 1,
#   "государством": 1,
#   "индустрией": 1,
#   "Портфель": 1,
#   "насчитывает": 1,
#   "62": 1,
#   "коммерческих": 2,
#   "ведущими": 1,
#   "компаниями": 1,
#   "реального": 1,
#   "сектора": 1,
#   "Госкорпорация": 1,
#   "Роскосмос": 1,
#   "Татнефть": 2,
#   "Danaflex": 2,
#   "РусГидро": 2,
#   "другие": 1,
#   "Общая": 1,
#   "сумма": 1,
#   "портфеля": 1,
#   "111": 1,
#   "грантовых": 1,
#   "03": 1,
#   "млрд": 7,
#   "национального": 1,
#   "экономика": 2,
#   "ведёт": 1,
#   "Грантовые": 1,
#   "флагманские": 2,
#   "проекты": 3,
#   "Система": 1,
#   "автоматического": 2,
#   "распознавания": 2,
#   "патологий": 1,
#   "легких": 1,
#   "рентгеновским": 1,
#   "изображениям": 1,
#   "применением": 6,
#   "ИИ": 1,
#   "AI": 1,
#   "RADIOLOGY": 1,
#   "Заказчик": 6,
#   "Департамент": 1,
#   "здравоохранения": 1,
#   "Москвы": 1,
#   "Разработка": 6,
#   "платформы": 2,
#   "автоматизации": 2,
#   "процессов": 1,
#   "управления": 3,
#   "корпоративными": 1,
#   "топливными": 1,
#   "картами": 1,
#   "распределённого": 3,
#   "реестра": 3,
#   "смарт": 1,
#   "контрактов": 1,
#   "CardLedger": 1,
#   "Российский": 2,
#   "фонд": 1,
#   "Коммерческие": 1,
#   "Интегрированная": 1,
#   "цифровая": 1,
#   "платформа": 3,
#   "геолого": 1,
#   "технологического": 1,
#   "мониторинга": 6,
#   "диагностики": 3,
#   "технического": 1,
#   "состояния": 1,
#   "компрессорных": 1,
#   "станций": 1,
#   "комплекса": 3,
#   "роботизированных": 1,
#   "передачи": 2,
#   "реальном": 1,
#   "времени": 1,
#   "документации": 2,
#   "трансформации": 1,
#   "внедрение": 1,
#   "предиктивной": 1,
#   "аналитики": 1,
#   "основе": 1,
#   "производства": 1,
#   "гибкой": 1,
#   "упаковки": 1,
#   "Лаборатории": 2,
#   "областях": 1,
#   "участников": 1,
#   "под": 2,
#   "руководством": 2,
#   "прикладные": 1,
#   "иностранные": 1,
#   "Франции": 1,
#   "Китая": 1,
#   "Дании": 1,
#   "Швеции": 1,
#   "Германии": 1,
#   "Норвегии": 1,
#   "компании": 3,
#   "Сбербанк": 2,
#   "Газпромнефть": 1,
#   "ВолГТУ": 1,
#   "внутри": 1,
#   "сформированы": 1,
#   "Научно": 1,
#   "технический": 1,
#   "совет": 4,
#   "Индустриальный": 1,
#   "координации": 1,
#   "работы": 4,
#   "исследовательской": 2,
#   "продуктов": 2,
#   "услуг": 1,
#   "сетевых": 1,
#   "беспилотных": 2,
#   "входящей": 1,
#   "состав": 3,
#   "собственные": 1,
#   "беспилотные": 1,
#   "летательные": 1,
#   "аппараты": 1,
#   "например": 1,
#   "конвертоплан": 1,
#   "который": 1,
#   "предназначен": 1,
#   "воздушных": 3,
#   "грузоперевозок": 1,
#   "создаётся": 1,
#   "взлетно": 1,
#   "посадочная": 1,
#   "БПЛА": 1,
#   "обеспечивающая": 1,
#   "полный": 1,
#   "цикл": 1,
#   "аппаратов": 1,
#   "Задачей": 1,
#   "беспилотника": 1,
#   "может": 4,
#   "быть": 1,
#   "мониторинг": 1,
#   "сельскохозяйственных": 2,
#   "угодий": 1,
#   "зданий": 1,
#   "сооружений": 1,
#   "или": 2,
#   "любой": 1,
#   "другой": 1,
#   "Внутри": 1,
#   "проводятся": 1,
#   "беспилотным": 1,
#   "транспортным": 1,
#   "системам": 1,
#   "KIA": 1,
#   "Soul": 1,
#   "Hyundai": 1,
#   "Santa": 1,
#   "Fe": 1,
#   "грузового": 1,
#   "Активно": 1,
#   "развивается": 2,
#   "направление": 1,
#   "электрификации": 1,
#   "транспортных": 1,
#   "разработка": 1,
#   "опытного": 1,
#   "образца": 1,
#   "помощи": 2,
#   "водителю": 1,
#   "ADAS": 1,
#   "над": 2,
#   "проекту": 1,
#   "ГИБДД": 1,
#   "цель": 1,
#   "программно": 1,
#   "аппаратного": 1,
#   "контроля": 1,
#   "сдачи": 1,
#   "практической": 1,
#   "части": 1,
#   "экзамена": 1,
#   "водительские": 1,
#   "права": 1,
#   "Кроме": 1,
#   "Лаборатория": 17,
#   "разработкой": 5,
#   "надводно": 1,
#   "подводного": 1,
#   "модуля": 1,
#   "подводной": 2,
#   "том": 1,
#   "числе": 3,
#   "подводных": 1,
#   "трубопроводов": 1,
#   "за": 4,
#   "счет": 1,
#   "применения": 1,
#   "новых": 1,
#   "технических": 1,
#   "решений": 2,
#   "Подобный": 1,
#   "комплекс": 1,
#   "обслуживаться": 1,
#   "оператором": 1,
#   "повышать": 1,
#   "достоверность": 1,
#   "скорость": 1,
#   "обследования": 1,
#   "Данный": 1,
#   "функционал": 1,
#   "распространяться": 1,
#   "смежные": 1,
#   "задачи": 1,
#   "действует": 1,
#   "когнитивных": 2,
#   "которой": 1,
#   "ведущая": 1,
#   "мировая": 1,
#   "школа": 1,
#   "нейронаук": 1,
#   "опубликованы": 1,
#   "самом": 1,
#   "престижном": 1,
#   "научном": 1,
#   "журнале": 1,
#   "мира": 1,
#   "Nature": 1,
#   "Scientific": 1,
#   "Reports": 1,
#   "Учёные": 1,
#   "этой": 2,
#   "профессора": 1,
#   "Александра": 1,
#   "Храмова": 1,
#   "совместно": 1,
#   "британским": 1,
#   "Лафборо": 1,
#   "первыми": 1,
#   "обнаружили": 1,
#   "новый": 1,
#   "способ": 1,
#   "хранения": 2,
#   "информации": 1,
#   "квантовых": 1,
#   "компьютеров": 1,
#   "изучив": 1,
#   "возможности": 1,
#   "обнаруженным": 1,
#   "гиперхаосом": 1,
#   "кубитах": 1,
#   "Сотрудники": 1,
#   "4D": 1,
#   "геоинформационную": 1,
#   "модель": 1,
#   "Аэронет": 1,
#   "компьютерного": 4,
#   "зрения": 4,
#   "машинного": 4,
#   "анализа": 6,
#   "изображений": 2,
#   "Это": 1,
#   "поможет": 1,
#   "своевременно": 1,
#   "находить": 1,
#   "даже": 1,
#   "небольшие": 1,
#   "очаги": 1,
#   "возгорания": 1,
#   "лесов": 1,
#   "фиксировать": 1,
#   "незаконные": 1,
#   "строения": 1,
#   "мониторить": 1,
#   "ж": 1,
#   "д": 1,
#   "путей": 1,
#   "нефтегазовых": 2,
#   "труб": 1,
#   "огромной": 1,
#   "июня": 1,
#   "облачная": 1,
#   "геоинформационная": 1,
#   "запущена": 1,
#   "эксплуатацию": 1,
#   "сервисов": 3,
#   "охранных": 1,
#   "зон": 1,
#   "объектов": 1,
#   "капитального": 1,
#   "строительства": 2,
#   "лесоизменений": 1,
#   "сельского": 1,
#   "хозяйства": 1,
#   "Телеагроном": 2,
#   "оперативного": 1,
#   "прогнозирования": 1,
#   "болезней": 1,
#   "культур": 1,
#   "Ежегодно": 1,
#   "обслуживает": 1,
#   "гектар": 3,
#   "пашни": 3,
#   "Республике": 2,
#   "Мордовия": 1,
#   "Внедрение": 1,
#   "точного": 1,
#   "земледелия": 1,
#   "применяется": 1,
#   "Татарстана": 1,
#   "Кировской": 1,
#   "Волгоградской": 1,
#   "Ключевым": 1,
#   "результатом": 1,
#   "2022": 7,
#   "стала": 1,
#   "экономия": 1,
#   "минеральных": 1,
#   "удобрений": 1,
#   "70": 1,
#   "литров": 1,
#   "баковой": 1,
#   "смеси": 1,
#   "КАС": 1,
#   "каждый": 1,
#   "обработанной": 1,
#   "Лидирующий": 2,
#   "исследовательский": 2,
#   "систем": 12,
#   "реализуется": 1,
#   "отраслевой": 1,
#   "проект": 1,
#   "Заправка": 1,
#   "судов": 2,
#   "ПАО": 1,
#   "ЛИЦ": 1,
#   "разработали": 1,
#   "индустриальный": 1,
#   "методов": 2,
#   "формальной": 1,
#   "верификации": 1,
#   "Innochain": 1,
#   "Универсальная": 1,
#   "система": 1,
#   "поддерживает": 1,
#   "операции": 1,
#   "нескольким": 1,
#   "процессам": 1,
#   "заправки": 1,
#   "оплаты": 1,
#   "ЖКУ": 1,
#   "Учебные": 1,
#   "2023": 3,
#   "учебном": 3,
#   "вузе": 3,
#   "обучаются": 3,
#   "077": 1,
#   "Студенты": 1,
#   "двум": 1,
#   "бакалаврским": 1,
#   "Информатика": 1,
#   "вычислительная": 1,
#   "техника": 1,
#   "Анализ": 2,
#   "искусственный": 2,
#   "интеллект": 2,
#   "пяти": 1,
#   "магистратуры": 6,
#   "Технологическое": 1,
#   "предпринимательство": 1,
#   "Робототехника": 2,
#   "компьютерное": 1,
#   "зрение": 1,
#   "программного": 2,
#   "обеспечения": 2,
#   "Компьютерная": 1,
#   "безопасность": 2,
#   "Две": 1,
#   "Теоретические": 1,
#   "основы": 1,
#   "информатики": 2,
#   "Математическое": 1,
#   "моделирование": 1,
#   "численные": 1,
#   "методы": 1,
#   "комплексы": 1,
#   "Образовательные": 1,
#   "включают": 1,
#   "175": 1,
#   "дисциплин": 1,
#   "третий": 1,
#   "бакалавриата": 5,
#   "могут": 1,
#   "выбрать": 1,
#   "одно": 1,
#   "четырёх": 1,
#   "направлений": 1,
#   "специализации": 1,
#   "ПО": 4,
#   "Большие": 1,
#   "данные": 1,
#   "Информационная": 1,
#   "существуют": 1,
#   "непрофильные": 1,
#   "направления": 1,
#   "игр": 2,
#   "Биотехнологии": 1,
#   "Финансовые": 1,
#   "технологи": 1,
#   "Blockchain": 1,
#   "Киберфизические": 1,
#   "4": 4,
#   "института": 2,
#   "готовят": 1,
#   "киберфизических": 2,
#   "программной": 4,
#   "инженерии": 4,
#   "Всего": 1,
#   "время": 1,
#   "существования": 1,
#   "выпустились": 1,
#   "850": 1,
#   "208": 1,
#   "У": 1,
#   "выпускников": 1,
#   "100": 3,
#   "трудоустройство": 1,
#   "российские": 1,
#   "Сбертех": 1,
#   "Яндекс": 1,
#   "Тинькофф": 1,
#   "S7": 1,
#   "Мегафон": 2,
#   "Qiwi": 1,
#   "МТС": 2,
#   "ОМП": 1,
#   "X5": 1,
#   "Retail": 1,
#   "Особенности": 1,
#   "Обучение": 1,
#   "бюджетное": 1,
#   "платное": 1,
#   "выделено": 2,
#   "52": 1,
#   "бюджетных": 3,
#   "стоимость": 2,
#   "800": 1,
#   "Абитуриент": 1,
#   "выиграть": 1,
#   "грант": 1,
#   "частично": 1,
#   "покрывающий": 1,
#   "дающий": 1,
#   "возможность": 1,
#   "получать": 1,
#   "стипендию": 1,
#   "36": 1,
#   "месяц": 1,
#   "Преподавание": 1,
#   "ведётся": 1,
#   "английском": 1,
#   "языке": 1,
#   "Руководство": 1,
#   "А": 1,
#   "Г": 1,
#   "ректор": 1,
#   "экс": 1,
#   "заведующий": 1,
#   "кафедрой": 1,
#   "теоретической": 1,
#   "прикладной": 1,
#   "директор": 3,
#   "Наблюдательный": 2,
#   "высший": 1,
#   "орган": 1,
#   "Наблюдательного": 1,
#   "входили": 1,
#   "Чернышенко": 1,
#   "заместитель": 3,
#   "председателя": 1,
#   "правительства": 1,
#   "Максут": 1,
#   "Шадаев": 1,
#   "Валерий": 1,
#   "Фальков": 1,
#   "Татьяна": 1,
#   "Илюшникова": 1,
#   "министра": 2,
#   "экономического": 1,
#   "Роман": 1,
#   "Шайхутдинов": 1,
#   "Борис": 1,
#   "Нуралиев": 1,
#   "1С": 1,
#   "Николай": 1,
#   "Никифоров": 1,
#   "председатель": 1,
#   "ООО": 8,
#   "Дигинавис": 1,
#   "Профессорско": 1,
#   "преподавательский": 1,
#   "преподают": 1,
#   "152": 1,
#   "педагогических": 1,
#   "сотрудника": 1,
#   "стран": 1,
#   "опытом": 1,
#   "мировой": 1,
#   "индустрии": 1,
#   "Samsung": 1,
#   "Research": 2,
#   "Intel": 1,
#   "Magna": 1,
#   "International": 1,
#   "ООН": 1,
#   "Численность": 1,
#   "086": 1,
#   "171": 1,
#   "дисциплине": 1,
#   "882": 1,
#   "823": 1,
#   "771": 1,
#   "254": 1,
#   "255": 1,
#   "313": 1,
#   "24": 1,
#   "322": 1,
#   "студента": 1,
#   "236": 1,
#   "86": 1,
#   "Структура": 1,
#   "структуру": 1,
#   "научных": 1,
#   "представления": 1,
#   "рук": 12,
#   "Адил": 1,
#   "Мехмуд": 1,
#   "Хан": 1,
#   "Занимается": 4,
#   "исследованиями": 2,
#   "алгоритмов": 1,
#   "глубинного": 1,
#   "обработки": 1,
#   "контекстно": 1,
#   "ориентированного": 1,
#   "автоматизированного": 1,
#   "моделирования": 1,
#   "онтологии": 1,
#   "обоснования": 1,
#   "Браун": 1,
#   "Джозеф": 1,
#   "Александер": 1,
#   "биоинформатики": 1,
#   "Ярослав": 1,
#   "Холодов": 1,
#   "нефтегазовой": 1,
#   "Мануэль": 1,
#   "Маццара": 1,
#   "среды": 1,
#   "высокой": 1,
#   "надёжности": 1,
#   "Джанкарло": 1,
#   "Суччи": 1,
#   "эмпирических": 1,
#   "исследовании": 1,
#   "программных": 1,
#   "качества": 2,
#   "операционных": 1,
#   "языков": 1,
#   "программирования": 1,
#   "компиляторов": 1,
#   "сетей": 1,
#   "Рашид": 1,
#   "Хуссейн": 1,
#   "кибер": 1,
#   "физических": 1,
#   "Альберто": 1,
#   "Силлитти": 1,
#   "облачных": 3,
#   "виртуализации": 2,
#   "интеллектуальных": 1,
#   "робототехнических": 2,
#   "Климчик": 1,
#   "дизайна": 1,
#   "электронных": 1,
#   "проектной": 1,
#   "работает": 1,
#   "лаборатория": 1,
#   "институт": 1,
#   "работающие": 1,
#   "проектами": 1,
#   "бизнеса": 1,
#   "Букин": 1,
#   "поколения": 1,
#   "интегрированной": 1,
#   "системой": 1,
#   "гарантированным": 1,
#   "уровнем": 1,
#   "доступа": 1,
#   "отказоустойчивости": 1,
#   "Рамиль": 1,
#   "Кулеев": 1,
#   "Михаил": 1,
#   "Серёгин": 1,
#   "геоинформационных": 1,
#   "Диана": 1,
#   "Низамова": 1,
#   "Алексей": 2,
#   "Дудниченко": 1,
#   "Сергей": 1,
#   "Чайников": 1,
#   "Павлов": 1,
#   "продвижения": 1,
#   "Марина": 1,
#   "Абдрахманова": 1,
#   "энергетики": 1,
#   "Ринат": 1,
#   "Мисбахов": 1,
#   "Кампус": 2,
#   "Университетский": 1,
#   "площадью": 2,
#   "31": 1,
#   "тысячи": 2,
#   "м²": 2,
#   "четыре": 1,
#   "корпуса": 4,
#   "общежитий": 1,
#   "1200": 1,
#   "35": 1,
#   "построены": 1,
#   "счёт": 2,
#   "федерального": 1,
#   "бюджета": 1,
#   "Государственной": 1,
#   "Экономическое": 1,
#   "инновационная": 1,
#   "линии": 1,
#   "это": 1,
#   "внесением": 1,
#   "уставной": 1,
#   "капитал": 1,
#   "ОАО": 9,
#   "7": 2,
#   "руб": 4,
#   "состоит": 1,
#   "лабораторного": 3,
#   "жилого": 3,
#   "спортивного": 3,
#   "комплексов": 2,
#   "Разработку": 1,
#   "проектно": 1,
#   "сметной": 1,
#   "первой": 2,
#   "очереди": 2,
#   "провело": 1,
#   "ЗАО": 1,
#   "Казанский": 1,
#   "Гипронииавиапром": 1,
#   "тендер": 1,
#   "выиграло": 1,
#   "Камгэсэнергострой": 2,
#   "Сумма": 2,
#   "контракта": 2,
#   "составила": 2,
#   "2": 2,
#   "07": 2,
#   "стало": 1,
#   "единственным": 1,
#   "участником": 1,
#   "тендера": 1,
#   "Финансирование": 1,
#   "Операционная": 1,
#   "финансируется": 1,
#   "спонсоров": 3,
#   "доходов": 1,
#   "собственной": 1,
#   "МегаФон": 1,
#   "АйСиЭл": 1,
#   "КПО": 2,
#   "ВС": 2,
#   "Инфомат": 1,
#   "Инвестнефтехим": 1,
#   "Корпоративные": 1,
#   "информационные": 1,
#   "рутины": 1,
#   "КИР": 1,
#   "частные": 2,
#   "лица": 2,
#   "Было": 1,
#   "привлечено": 1,
#   "437": 1,
#   "АЙСИЭЛ": 1,
#   "Акронис": 1,
#   "ДНК": 1,
#   "Технология": 1,
#   "Параллелз": 1,
#   "рисерч": 1,
#   "Связьинвестнефтехим": 1,
#   "Тесис": 1,
#   "По": 1,
#   "Университету": 1,
#   "удалось": 1,
#   "привлечь": 1,
#   "651": 1,
#   "спонсорских": 1,
#   "выиграл": 1,
#   "гранты": 1,
#   "сумму": 1,
#   "федеральную": 1,
#   "субсидию": 1,
#   "размере": 1,
#   "Сотрудничество": 1,
#   "Помимо": 1,
#   "Меллон": 1,
#   "сотрудничает": 1,
#   "Швейцарской": 1,
#   "высшей": 1,
#   "технической": 1,
#   "школой": 2,
#   "Цюриха": 1,
#   "Национальным": 1,
#   "университетом": 5,
#   "Сингапура": 1,
#   "Амстердама": 1,
#   "Корейским": 1,
#   "институтом": 2,
#   "передовых": 1,
#   "Московским": 3,
#   "техническим": 2,
#   "государственным": 2,
#   "юридическим": 1,
#   "имени": 1,
#   "Е": 1,
#   "Кутафина": 1,
#   "Высшей": 1,
#   "Казанским": 2,
#   "национальным": 1,
#   "исследовательским": 1,
#   "другими": 1,
#   "российскими": 1,
#   "зарубежными": 1,
#   "вузами": 1,
#   "Рейтинги": 1,
#   "занял": 2,
#   "12": 1,
#   "место": 2,
#   "рейтинге": 2,
#   "лучших": 1,
#   "журнала": 1,
#   "Forbes": 1,
#   "вошёл": 1,
#   "топ": 3,
#   "рейтинга": 1,
#   "U": 1,
#   "Multirank": 1,
#   "категории": 2,
#   "Совместные": 1,
#   "международные": 1,
#   "публикации": 1,
#   "Рейтинг": 1,
#   "основан": 1,
#   "при": 1,
#   "финансовой": 1,
#   "Еврокомиссии": 1,
#   "Erasmus": 1,
#   "первым": 1,
#   "российским": 1,
#   "вузом": 1,
#   "вошедшим": 1,
#   "занимает": 1,
#   "74": 1,
#   "Institutions": 1,
#   "Active": 1,
#   "in": 1,
#   "Technical": 1,
#   "Games": 1,
#   "составленным": 1,
#   "профессором": 1,
#   "компьютерных": 1,
#   "Американского": 1,
#   "Вашингтоне": 1,
#   "Марком": 1,
#   "Нельсоном": 1,
#   "Согласно": 1,
#   "рейтингу": 1,
#   "приёма": 1,
#   "средний": 1,
#   "балл": 1,
#   "ЕГЭ": 1,
#   "зачисленных": 1,
#   "курс": 1,
#   "99": 1,
#   "бюджетный": 1,
#   "набор": 2,
#   "95": 1,
#   "90": 1,
#   "основной": 1,
#   "платному": 1,
#   "набору": 1,
#   "вошел": 1,
#   "Международный": 1,
#   "рейтинг": 1,
#   "Три": 1,
#   "миссии": 1,
#   "где": 1,
#   "позицию": 1,
#   "диапазоне": 1,
#   "601": 1,
#   "650": 1,
#   "Примечания": 1,
#   "Источники": 1,
#   "запустила": 1,
#   "уникальную": 1,
#   "грантовую": 1,
#   "программу": 1,
#   "поддержки": 1,
#   "Министерство": 1,
#   "23": 1
# }
#
#
# For english text: {
#   "Иннопо": 1,
#   "лис": 1,
#   "город": 9,
#   "в": 108,
#   "Верхнеуслонском": 2,
#   "районе": 2,
#   "Республики": 12,
#   "Татарстан": 15,
#   "спутник": 1,
#   "Казани": 6,
#   "входящий": 1,
#   "её": 1,
#   "агломерацию": 1,
#   "В": 27,
#   "нём": 3,
#   "расположены": 3,
#   "Университет": 7,
#   "Иннополис": 48,
#   "и": 98,
#   "особая": 2,
#   "экономическая": 6,
#   "зона": 6,
#   "Является": 1,
#   "одним": 1,
#   "из": 9,
#   "трёх": 1,
#   "наукоградов": 1,
#   "Российской": 3,
#   "Федерации": 3,
#   "наряду": 1,
#   "с": 27,
#   "подмосковным": 1,
#   "центром": 3,
#   "Сколково": 2,
#   "новосибирским": 1,
#   "Кольцово": 1,
#   "созданных": 1,
#   "для": 18,
#   "развития": 2,
#   "информационных": 5,
#   "технологий": 9,
#   "инновационных": 2,
#   "высоких": 3,
#   "Один": 1,
#   "немногих": 1,
#   "построенных": 2,
#   "нуля": 2,
#   "городов": 1,
#   "постсоветской": 1,
#   "России": 6,
#   "Образует": 1,
#   "городское": 1,
#   "поселение": 2,
#   "Физико": 1,
#   "географическая": 1,
#   "характеристика": 1,
#   "Расположение": 1,
#   "находится": 4,
#   "40": 1,
#   "километрах": 1,
#   "от": 13,
#   "на": 58,
#   "правом": 1,
#   "склоне": 1,
#   "Куйбышевского": 2,
#   "водохранилища": 4,
#   "напротив": 1,
#   "Свияжска": 1,
#   "Координаты": 1,
#   "центра": 3,
#   "55": 1,
#   "45": 1,
#   "ш": 1,
#   "48": 1,
#   "44": 1,
#   "д": 1,
#   "часовой": 1,
#   "пояс": 1,
#   "UTC": 1,
#   "3": 5,
#   "московское": 1,
#   "время": 3,
#   "География": 1,
#   "Территория": 2,
#   "города": 31,
#   "характеризуется": 1,
#   "значительными": 1,
#   "перепадами": 1,
#   "высот": 1,
#   "центральной": 3,
#   "южной": 1,
#   "частей": 1,
#   "начинается": 1,
#   "понижение": 1,
#   "рельефа": 2,
#   "сторону": 1,
#   "акватории": 1,
#   "по": 16,
#   "части": 2,
#   "проходит": 1,
#   "водораздел": 1,
#   "рек": 1,
#   "Свияга": 2,
#   "Сулица": 1,
#   "Морвашка": 1,
#   "Высота": 1,
#   "над": 1,
#   "уровнем": 1,
#   "моря": 1,
#   "составляет": 3,
#   "200": 1,
#   "220": 1,
#   "метров": 1,
#   "тогда": 1,
#   "как": 5,
#   "к": 6,
#   "урезу": 1,
#   "высота": 1,
#   "уменьшается": 2,
#   "до": 7,
#   "53": 1,
#   "м": 1,
#   "Общий": 1,
#   "уклон": 1,
#   "территории": 10,
#   "среднем": 1,
#   "2": 9,
#   "1": 9,
#   "север": 1,
#   "северо": 1,
#   "запад": 1,
#   "местами": 1,
#   "достигает": 1,
#   "10": 3,
#   "Город": 3,
#   "Казанской": 1,
#   "сейсмогенной": 1,
#   "зоне": 3,
#   "активность": 1,
#   "которой": 3,
#   "обусловлена": 1,
#   "техногенными": 1,
#   "факторами": 1,
#   "закачкой": 1,
#   "вод": 1,
#   "поддержания": 1,
#   "пластового": 1,
#   "давления": 1,
#   "при": 8,
#   "нефтедобыче": 1,
#   "а": 2,
#   "также": 3,
#   "созданием": 1,
#   "Сейсмическая": 1,
#   "интенсивность": 1,
#   "оценивается": 1,
#   "6": 4,
#   "баллов": 1,
#   "шкале": 1,
#   "Рихтера": 1,
#   "Климат": 2,
#   "Иннополиса": 20,
#   "умеренно": 1,
#   "континентальный": 1,
#   "формируется": 1,
#   "под": 3,
#   "воздействием": 1,
#   "резко": 1,
#   "континентальных": 2,
#   "воздушных": 1,
#   "масс": 1,
#   "Азии": 1,
#   "западного": 1,
#   "переноса": 1,
#   "На": 7,
#   "климатические": 1,
#   "особенности": 2,
#   "влияет": 1,
#   "Куйбышевское": 1,
#   "водохранилище": 1,
#   "имеющее": 1,
#   "морские": 1,
#   "свойства": 1,
#   "условиях": 1,
#   "Поволжья": 1,
#   "прибрежной": 1,
#   "выше": 1,
#   "облачность": 1,
#   "количество": 1,
#   "осадков": 2,
#   "удлиняется": 1,
#   "период": 1,
#   "положительными": 1,
#   "температурами": 1,
#   "число": 1,
#   "дней": 1,
#   "заморозками": 1,
#   "Преобладают": 1,
#   "южные": 1,
#   "юго": 1,
#   "западные": 2,
#   "ветра": 1,
#   "что": 1,
#   "особенно": 1,
#   "выражено": 1,
#   "холодный": 1,
#   "сезон": 1,
#   "когда": 2,
#   "образуется": 2,
#   "развивается": 1,
#   "сибирский": 1,
#   "антициклон": 1,
#   "Количество": 1,
#   "умеренное": 1,
#   "тёплого": 1,
#   "сезона": 1,
#   "характерны": 1,
#   "грозы": 1,
#   "холодного": 1,
#   "метели": 1,
#   "Устойчивый": 1,
#   "снежный": 1,
#   "покров": 1,
#   "середине": 2,
#   "ноября": 5,
#   "сходит": 1,
#   "апреля": 3,
#   "Растительность": 1,
#   "Вследствие": 1,
#   "интенсивного": 1,
#   "освоения": 1,
#   "значительная": 1,
#   "часть": 3,
#   "окружающих": 1,
#   "земель": 1,
#   "распахана": 1,
#   "занята": 1,
#   "сельскохозяйственными": 1,
#   "культурами": 1,
#   "естественная": 1,
#   "растительность": 1,
#   "сохранилась": 1,
#   "участках": 1,
#   "неудобных": 1,
#   "ведения": 1,
#   "сельского": 4,
#   "хозяйства": 2,
#   "расположена": 1,
#   "памятника": 1,
#   "природы": 1,
#   "регионального": 2,
#   "значения": 3,
#   "Зоостанция": 1,
#   "КГУ": 1,
#   "массив": 1,
#   "Дачный": 1,
#   "включающего": 1,
#   "территорию": 1,
#   "зоологической": 1,
#   "станции": 1,
#   "Казанского": 1,
#   "государственного": 1,
#   "университета": 3,
#   "широколиственные": 1,
#   "леса": 1,
#   "Свияжского": 1,
#   "лесничества": 1,
#   "острова": 1,
#   "сохранившимися": 1,
#   "участками": 1,
#   "пойменных": 1,
#   "лугов": 1,
#   "западе": 1,
#   "граничит": 1,
#   "заказником": 1,
#   "Свияжский": 1,
#   "основной": 1,
#   "зоной": 3,
#   "Большого": 1,
#   "Волжско": 1,
#   "Камского": 1,
#   "природного": 2,
#   "резервата": 1,
#   "История": 2,
#   "Проект": 2,
#   "Идею": 1,
#   "создания": 3,
#   "пригороде": 1,
#   "инновационного": 2,
#   "впервые": 1,
#   "озвучил": 1,
#   "Президент": 1,
#   "Татарстана": 5,
#   "Рустам": 3,
#   "Минниханов": 5,
#   "ежегодном": 1,
#   "послании": 1,
#   "Государственного": 3,
#   "Совета": 2,
#   "2010": 1,
#   "году": 8,
#   "рабочим": 1,
#   "названием": 1,
#   "IT": 9,
#   "деревня": 2,
#   "предполагал": 1,
#   "строительство": 5,
#   "населённого": 1,
#   "пункта": 2,
#   "офисными": 1,
#   "зданиями": 2,
#   "жилыми": 1,
#   "домами": 1,
#   "спортивной": 1,
#   "рекреационной": 1,
#   "образовательной": 1,
#   "инфраструктурой": 1,
#   "рассчитанного": 3,
#   "проживание": 1,
#   "50": 1,
#   "тысяч": 7,
#   "человек": 6,
#   "порядка": 1,
#   "20": 2,
#   "специалистов": 4,
#   "области": 4,
#   "членов": 1,
#   "их": 1,
#   "семей": 1,
#   "Деревня": 1,
#   "рассматривалась": 1,
#   "развитие": 1,
#   "успешного": 1,
#   "опыта": 1,
#   "крупнейшего": 1,
#   "Восточной": 1,
#   "Европе": 1,
#   "технопарка": 4,
#   "сфере": 2,
#   "ИТ": 3,
#   "парк": 2,
#   "потенциальный": 1,
#   "партнёр": 2,
#   "или": 2,
#   "филиал": 1,
#   "московского": 1,
#   "подобную": 1,
#   "возможность": 4,
#   "обсуждал": 1,
#   "встрече": 1,
#   "заместителем": 1,
#   "председателя": 1,
#   "Правительства": 3,
#   "Аркадием": 1,
#   "Дворковичем": 1,
#   "Для": 5,
#   "деревни": 1,
#   "было": 7,
#   "выделено": 2,
#   "4": 8,
#   "тысячи": 5,
#   "гектаров": 1,
#   "августе": 6,
#   "2011": 2,
#   "года": 47,
#   "контракт": 1,
#   "разработку": 1,
#   "мастер": 3,
#   "плана": 3,
#   "получило": 2,
#   "сингапурское": 1,
#   "архитектурно": 1,
#   "планировочное": 1,
#   "бюро": 1,
#   "RSP": 2,
#   "Architects": 1,
#   "Planners": 1,
#   "Engineers": 1,
#   "руководством": 1,
#   "бывшего": 1,
#   "главного": 1,
#   "архитектора": 1,
#   "Сингапура": 2,
#   "Лиу": 2,
#   "Тай": 2,
#   "Кера": 1,
#   "ноябре": 1,
#   "будущий": 1,
#   "получил": 2,
#   "название": 4,
#   "охарактеризованное": 1,
#   "министром": 1,
#   "информатизации": 2,
#   "связи": 5,
#   "Николаем": 1,
#   "Никифоровым": 1,
#   "более": 4,
#   "точно": 1,
#   "отражающее": 1,
#   "суть": 1,
#   "проекта": 2,
#   "апреле": 2,
#   "2012": 6,
#   "Кер": 1,
#   "посетил": 1,
#   "Казань": 8,
#   "презентации": 1,
#   "во": 2,
#   "обсуждений": 1,
#   "руководство": 1,
#   "республики": 5,
#   "рекомендации": 1,
#   "увеличило": 1,
#   "проектную": 1,
#   "численность": 1,
#   "населения": 2,
#   "155": 1,
#   "чтобы": 1,
#   "обеспечить": 1,
#   "будущему": 1,
#   "городу": 3,
#   "потенциал": 1,
#   "роста": 1,
#   "несколько": 4,
#   "десятилетий": 1,
#   "вперёд": 1,
#   "дальнейшего": 1,
#   "проектирования": 1,
#   "учитывающего": 1,
#   "российского": 1,
#   "законодательства": 1,
#   "градостроительства": 1,
#   "помощь": 1,
#   "сингапурским": 1,
#   "архитекторам": 1,
#   "была": 5,
#   "привлечена": 1,
#   "компания": 5,
#   "Казанский": 1,
#   "Гипронииавиапром": 1,
#   "Начало": 1,
#   "строительства": 6,
#   "основали": 1,
#   "9": 4,
#   "июня": 2,
#   "тот": 1,
#   "день": 1,
#   "Дмитрий": 2,
#   "Медведев": 2,
#   "заложили": 1,
#   "основание": 1,
#   "капсулу": 1,
#   "посланием": 1,
#   "будущим": 1,
#   "горожанам": 1,
#   "Сердце": 1,
#   "С": 6,
#   "него": 1,
#   "начали": 1,
#   "Рядом": 1,
#   "разместили": 1,
#   "студенческие": 1,
#   "общежития": 1,
#   "спорткомплекс": 1,
#   "Первая": 2,
#   "очередь": 3,
#   "2014": 7,
#   "образовала": 1,
#   "своеобразный": 1,
#   "треугольник": 1,
#   "кампус": 1,
#   "Университета": 3,
#   "технопарк": 1,
#   "имени": 3,
#   "Александра": 1,
#   "Степановича": 1,
#   "Попова": 4,
#   "жилые": 1,
#   "дома": 2,
#   "Окончательный": 1,
#   "план": 3,
#   "представили": 1,
#   "уже": 1,
#   "23": 1,
#   "августа": 3,
#   "Министерство": 3,
#   "земельных": 3,
#   "имущественных": 2,
#   "отношений": 2,
#   "Центральный": 1,
#   "депозитарий": 1,
#   "управляющая": 2,
#   "Проминвест": 1,
#   "связанная": 1,
#   "депутатом": 1,
#   "совета": 1,
#   "Равилем": 1,
#   "Зингашевым": 1,
#   "равных": 1,
#   "долях": 1,
#   "учредили": 1,
#   "компанию": 1,
#   "владельца": 1,
#   "земли": 2,
#   "будущего": 2,
#   "ОАО": 2,
#   "позднее": 2,
#   "переменнованую": 1,
#   "Сити": 2,
#   "Регистрация": 1,
#   "новой": 1,
#   "административно": 2,
#   "территориальной": 1,
#   "единицы": 1,
#   "могла": 1,
#   "затянуться": 1,
#   "лет": 2,
#   "поэтому": 1,
#   "власти": 4,
#   "летом": 2,
#   "прорабатывали": 1,
#   "дать": 1,
#   "новое": 2,
#   "соседней": 1,
#   "деревне": 1,
#   "Елизаветино": 2,
#   "однако": 2,
#   "Федеральная": 1,
#   "служба": 2,
#   "государственной": 1,
#   "регистрации": 1,
#   "кадастра": 1,
#   "картографии": 1,
#   "формальным": 1,
#   "основаниям": 1,
#   "отказала": 1,
#   "переименовании": 1,
#   "Осенью": 1,
#   "поселениях": 1,
#   "Верхнеуслонского": 6,
#   "района": 6,
#   "прошли": 1,
#   "общественные": 1,
#   "слушания": 1,
#   "которых": 2,
#   "поддержку": 1,
#   "предложение": 1,
#   "нового": 4,
#   "поселения": 4,
#   "оно": 1,
#   "передано": 1,
#   "Государственный": 1,
#   "Совет": 1,
#   "который": 6,
#   "24": 4,
#   "декабря": 5,
#   "принял": 1,
#   "постановление": 1,
#   "Об": 1,
#   "образовании": 1,
#   "населенного": 1,
#   "Введенско": 2,
#   "Слободского": 3,
#   "2013": 3,
#   "посёлок": 1,
#   "26": 5,
#   "депутаты": 1,
#   "проголосовали": 1,
#   "за": 3,
#   "присвоение": 1,
#   "посёлку": 1,
#   "статуса": 3,
#   "января": 2,
#   "2015": 12,
#   "решение": 1,
#   "закреплено": 1,
#   "законом": 2,
#   "подписанным": 2,
#   "Президентом": 1,
#   "13": 2,
#   "Открытие": 1,
#   "официально": 2,
#   "открыли": 1,
#   "через": 4,
#   "после": 4,
#   "основания": 1,
#   "церемонии": 1,
#   "приняли": 1,
#   "участие": 4,
#   "Николай": 2,
#   "Никифоров": 2,
#   "которые": 4,
#   "дали": 2,
#   "старт": 1,
#   "новому": 1,
#   "нажатием": 1,
#   "символической": 1,
#   "кнопки": 1,
#   "К": 4,
#   "открытию": 2,
#   "были": 4,
#   "приурочены": 1,
#   "начало": 1,
#   "форума": 2,
#   "РИФ": 1,
#   "конференции": 1,
#   "OS": 1,
#   "Day": 1,
#   "Всероссийской": 1,
#   "робототехнической": 1,
#   "олимпиады": 1,
#   "этому": 1,
#   "времени": 1,
#   "близка": 1,
#   "завершению": 1,
#   "первая": 1,
#   "инвестиции": 1,
#   "которую": 1,
#   "оценило": 1,
#   "миллиардов": 1,
#   "рублей": 7,
#   "закончилось": 1,
#   "возведение": 1,
#   "корпуса": 1,
#   "Технопарка": 1,
#   "спортивного": 2,
#   "комплекса": 4,
#   "здания": 4,
#   "студенческого": 1,
#   "кампуса": 2,
#   "жилых": 3,
#   "домов": 7,
#   "инженерной": 1,
#   "инфраструктуры": 1,
#   "названия": 2,
#   "Руководство": 1,
#   "широко": 1,
#   "использовало": 1,
#   "ранее": 1,
#   "запланированный": 1,
#   "технологический": 1,
#   "кластер": 1,
#   "обозначался": 1,
#   "авторство": 1,
#   "претендуют": 1,
#   "две": 1,
#   "стороны": 1,
#   "совладелица": 1,
#   "креативного": 1,
#   "агентства": 1,
#   "Evolutiom": 1,
#   "Арина": 1,
#   "Судакова": 1,
#   "венчурного": 1,
#   "фонда": 2,
#   "Formula": 1,
#   "VC": 1,
#   "Venture": 1,
#   "Fund": 1,
#   "Рената": 1,
#   "Ахунова": 1,
#   "Топоним": 1,
#   "был": 8,
#   "закреплён": 1,
#   "постановлением": 2,
#   "394": 1,
#   "О": 2,
#   "присвоении": 1,
#   "наименования": 1,
#   "географическому": 1,
#   "объекту": 1,
#   "Республике": 3,
#   "Этнохороним": 1,
#   "жителей": 2,
#   "иннополисяне": 1,
#   "Население": 1,
#   "Первые": 1,
#   "зарегистрированные": 1,
#   "жители": 2,
#   "появились": 1,
#   "Иннополисе": 12,
#   "ноябрь": 1,
#   "2016": 13,
#   "зарегистрированы": 1,
#   "месту": 1,
#   "жительства": 1,
#   "102": 1,
#   "человека": 1,
#   "ещё": 2,
#   "около": 2,
#   "5": 5,
#   "арендовали": 1,
#   "жильё": 2,
#   "По": 4,
#   "данным": 2,
#   "министерства": 1,
#   "конец": 1,
#   "52": 1,
#   "сотрудников": 3,
#   "являлись": 1,
#   "приезжими": 1,
#   "других": 1,
#   "регионов": 1,
#   "официального": 1,
#   "сайта": 1,
#   "фактически": 1,
#   "проживает": 1,
#   "8": 2,
#   "Численность": 1,
#   "дневного": 1,
#   "2020": 12,
#   "год": 11,
#   "сравнению": 1,
#   "показателем": 1,
#   "2019": 7,
#   "выросла": 1,
#   "17": 1,
#   "тыс": 4,
#   "Из": 1,
#   "них": 1,
#   "7": 5,
#   "проживают": 1,
#   "постоянно": 1,
#   "Власть": 1,
#   "Административное": 1,
#   "устройство": 1,
#   "До": 1,
#   "получения": 2,
#   "являлся": 1,
#   "посёлком": 1,
#   "составе": 1,
#   "соответствии": 2,
#   "115": 1,
#   "ЗРТ": 1,
#   "принятым": 1,
#   "Государственным": 2,
#   "Советом": 1,
#   "Рустамом": 1,
#   "Миннихановым": 1,
#   "преобразован": 1,
#   "районного": 1,
#   "Одновременно": 1,
#   "состава": 1,
#   "Введенского": 1,
#   "муниципальное": 1,
#   "образование": 1,
#   "Городское": 1,
#   "Органы": 1,
#   "Муниципальная": 1,
#   "власть": 1,
#   "осуществляется": 1,
#   "основании": 1,
#   "Устава": 1,
#   "принятого": 1,
#   "сходом": 1,
#   "граждан": 3,
#   "февраля": 2,
#   "Высшим": 1,
#   "должностным": 1,
#   "лицом": 1,
#   "является": 1,
#   "мэр": 2,
#   "избираемый": 1,
#   "сроком": 1,
#   "исполняющий": 1,
#   "полномочия": 1,
#   "главы": 1,
#   "местной": 1,
#   "администрации": 1,
#   "Исполнительного": 1,
#   "комитета": 1,
#   "результатам": 1,
#   "голосования": 1,
#   "состоявшегося": 1,
#   "25": 3,
#   "первым": 1,
#   "мэром": 2,
#   "стал": 1,
#   "Егор": 1,
#   "Иванов": 1,
#   "бывший": 1,
#   "генеральный": 1,
#   "директор": 1,
#   "телекоммуникационной": 1,
#   "компании": 5,
#   "Скартел": 1,
#   "новым": 1,
#   "избран": 1,
#   "Руслан": 1,
#   "Шагалеев": 1,
#   "Полномочия": 1,
#   "органа": 1,
#   "представительной": 1,
#   "осуществляет": 1,
#   "сход": 1,
#   "Городской": 1,
#   "бюджет": 5,
#   "У": 1,
#   "есть": 2,
#   "муниципальная": 1,
#   "собственность": 1,
#   "том": 1,
#   "числе": 1,
#   "объекты": 4,
#   "дорожного": 1,
#   "лесопарковая": 1,
#   "полоса": 1,
#   "городской": 3,
#   "Основной": 1,
#   "частью": 2,
#   "кроме": 1,
#   "ОЭЗ": 15,
#   "владеет": 2,
#   "АО": 5,
#   "управляет": 1,
#   "им": 3,
#   "АНО": 1,
#   "ВО": 1,
#   "принадлежит": 1,
#   "Государственному": 1,
#   "жилищному": 1,
#   "фонду": 1,
#   "остальные": 1,
#   "принадлежат": 1,
#   "акционерному": 1,
#   "обществу": 1,
#   "Особая": 4,
#   "Кроме": 1,
#   "того": 1,
#   "большинство": 1,
#   "зарегистрированных": 1,
#   "компаний": 7,
#   "освобождено": 1,
#   "уплаты": 1,
#   "налогов": 1,
#   "местный": 1,
#   "резиденты": 1,
#   "особой": 4,
#   "экономической": 4,
#   "зоны": 6,
#   "Решением": 1,
#   "схода": 1,
#   "утверждён": 1,
#   "уровне": 1,
#   "9373": 1,
#   "миллиона": 3,
#   "Плановый": 1,
#   "составил": 2,
#   "3909": 1,
#   "2017": 6,
#   "509": 1,
#   "Источник": 1,
#   "доходов": 2,
#   "муниципального": 5,
#   "образования": 3,
#   "Экономика": 1,
#   "Городская": 1,
#   "инфраструктура": 2,
#   "Основу": 1,
#   "жилищного": 1,
#   "составляют": 1,
#   "кварталов": 1,
#   "многоэтажных": 1,
#   "всего": 1,
#   "22": 1,
#   "1572": 1,
#   "квартиры": 1,
#   "жилищным": 1,
#   "фондом": 1,
#   "Президенте": 1,
#   "предназначенных": 1,
#   "сдачи": 1,
#   "аренду": 1,
#   "резидентам": 1,
#   "октябре": 2,
#   "переданы": 2,
#   "группе": 1,
#   "планировавшей": 1,
#   "выступать": 1,
#   "оператором": 1,
#   "арендного": 1,
#   "жилья": 1,
#   "резидентов": 5,
#   "договорённости": 1,
#   "большинству": 1,
#   "расторгнуты": 1,
#   "июле": 2,
#   "пресс": 1,
#   "сообщала": 1,
#   "о": 3,
#   "заселении": 1,
#   "420": 1,
#   "квартир": 4,
#   "Также": 1,
#   "городе": 3,
#   "работает": 5,
#   "частная": 1,
#   "девелопер": 1,
#   "занимающаяся": 1,
#   "малоэтажной": 1,
#   "блокированной": 1,
#   "застройкой": 1,
#   "проект": 3,
#   "предполагает": 1,
#   "сдачу": 1,
#   "80": 1,
#   "январь": 2,
#   "построено": 1,
#   "18": 1,
#   "арендных": 1,
#   "1006": 1,
#   "2021": 2,
#   "началось": 1,
#   "жилого": 1,
#   "многоэтажной": 1,
#   "застройки": 1,
#   "275": 1,
#   "планируется": 1,
#   "сдаче": 1,
#   "I": 1,
#   "кв": 1,
#   "2024": 1,
#   "состоянию": 1,
#   "действуют": 2,
#   "детский": 2,
#   "сад": 2,
#   "школа": 3,
#   "лицей": 2,
#   "153": 1,
#   "ученика": 1,
#   "спортивный": 2,
#   "комплекс": 2,
#   "медицинский": 3,
#   "центр": 6,
#   "отделение": 1,
#   "почты": 1,
#   "клиентские": 1,
#   "офисы": 1,
#   "банка": 1,
#   "АК": 1,
#   "Барс": 1,
#   "Сбербанка": 1,
#   "коворкинг": 1,
#   "Пункт": 1,
#   "выдачи": 1,
#   "заказов": 1,
#   "ОЗОН": 1,
#   "два": 2,
#   "салона": 1,
#   "красоты": 1,
#   "три": 1,
#   "супермаркета": 1,
#   "Бахетле": 1,
#   "Пятёрочка": 1,
#   "Магнит": 2,
#   "бары": 1,
#   "кафе": 1,
#   "прокат": 1,
#   "оборудования": 2,
#   "цветочный": 1,
#   "магазин": 2,
#   "Дом": 1,
#   "книги": 1,
#   "хобби": 1,
#   "другие": 3,
#   "привлечения": 1,
#   "инфраструктурных": 1,
#   "организаций": 1,
#   "общественного": 1,
#   "питания": 1,
#   "аптек": 1,
#   "учреждений": 1,
#   "досуга": 1,
#   "розничных": 1,
#   "магазинов": 1,
#   "Госжилфонд": 1,
#   "предложил": 1,
#   "арендаторам": 1,
#   "м²": 7,
#   "коммерческой": 1,
#   "недвижимости": 1,
#   "первых": 1,
#   "этажах": 1,
#   "месячной": 1,
#   "ставке": 1,
#   "100": 3,
#   "Вокруг": 1,
#   "растёт": 1,
#   "рекреационная": 1,
#   "Недалеко": 1,
#   "курорт": 1,
#   "Свияжские": 1,
#   "холмы": 1,
#   "горнолыжный": 1,
#   "гольф": 2,
#   "клуб": 2,
#   "боулинг": 1,
#   "wellness": 1,
#   "участии": 1,
#   "президента": 1,
#   "Рустама": 1,
#   "открыт": 1,
#   "двухэтажный": 1,
#   "культурный": 1,
#   "ArtSpace": 1,
#   "площадью": 5,
#   "Энергоузел": 1,
#   "включает": 2,
#   "построенные": 1,
#   "автоматическую": 1,
#   "котельную": 1,
#   "мощностью": 2,
#   "32": 2,
#   "МВт": 1,
#   "предусматривающую": 1,
#   "использование": 1,
#   "газа": 1,
#   "дизельного": 1,
#   "топлива": 1,
#   "главную": 1,
#   "понизительную": 1,
#   "подстанцию": 2,
#   "напряжением": 1,
#   "110": 1,
#   "кВ": 1,
#   "которая": 2,
#   "запитана": 1,
#   "подстанции": 1,
#   "Свияжск": 2,
#   "Исаково": 1,
#   "кабельно": 1,
#   "воздушной": 1,
#   "линии": 2,
#   "протяжённостью": 1,
#   "31": 2,
#   "километра": 1,
#   "Водоснабжение": 1,
#   "обеспечено": 1,
#   "поверхностным": 1,
#   "водозабором": 1,
#   "проектной": 1,
#   "2000": 1,
#   "м³": 1,
#   "сутки": 1,
#   "водоподготовка": 1,
#   "водоочистка": 1,
#   "применяются": 1,
#   "объеме": 1,
#   "необходимым": 1,
#   "качества": 1,
#   "питьевого": 1,
#   "Бытовые": 1,
#   "стоки": 1,
#   "очищаются": 1,
#   "отводятся": 1,
#   "Волгу": 1,
#   "дождевые": 1,
#   "талые": 1,
#   "воды": 1,
#   "понижения": 1,
#   "ливневая": 1,
#   "канализация": 1,
#   "отсутствует": 1,
#   "Первый": 1,
#   "газопровод": 1,
#   "предназначенный": 1,
#   "снабжения": 1,
#   "строительных": 1,
#   "объектов": 1,
#   "завершён": 1,
#   "спустя": 1,
#   "проведён": 1,
#   "отвод": 1,
#   "магистрального": 1,
#   "газопровода": 2,
#   "Горький": 1,
#   "запланировано": 1,
#   "завершение": 1,
#   "будет": 3,
#   "подключён": 1,
#   "магистральному": 1,
#   "газопроводу": 1,
#   "Уренгой": 1,
#   "Помары": 1,
#   "Ужгород": 1,
#   "настоящее": 1,
#   "подключение": 1,
#   "выполнено": 1,
#   "сентябре": 1,
#   "Мегафон": 1,
#   "провёл": 1,
#   "волоконно": 1,
#   "оптическую": 1,
#   "линию": 1,
#   "обеспечивающую": 1,
#   "соединение": 1,
#   "скорости": 1,
#   "Гбит": 1,
#   "Обсуждение": 1,
#   "городских": 1,
#   "проблем": 1,
#   "общественный": 1,
#   "контроль": 1,
#   "общение": 1,
#   "представителями": 1,
#   "организовано": 1,
#   "групповом": 1,
#   "чате": 1,
#   "мессенджере": 1,
#   "Telegram": 2,
#   "участниками": 1,
#   "которого": 1,
#   "являются": 1,
#   "министров": 1,
#   "главный": 1,
#   "архитектор": 1,
#   "ректор": 1,
#   "горожане": 1,
#   "Через": 1,
#   "улучшено": 1,
#   "расписание": 1,
#   "автобусов": 1,
#   "пролоббирована": 1,
#   "установка": 1,
#   "велопарковок": 1,
#   "возле": 1,
#   "основных": 1,
#   "зданий": 1,
#   "Круглосуточный": 1,
#   "консьерж": 1,
#   "сервис": 1,
#   "обрабатывает": 1,
#   "обращения": 1,
#   "городские": 1,
#   "службы": 1,
#   "Опыт": 1,
#   "предложено": 1,
#   "перенять": 1,
#   "московским": 1,
#   "чиновникам": 1,
#   "рамках": 2,
#   "VII": 1,
#   "Гражданского": 1,
#   "Москве": 3,
#   "Транспорт": 1,
#   "Транспортная": 1,
#   "доступность": 1,
#   "обеспечена": 1,
#   "подъездными": 1,
#   "автомобильными": 1,
#   "дорогами": 1,
#   "отходящими": 1,
#   "автомобильной": 1,
#   "дороги": 2,
#   "федерального": 2,
#   "М7": 1,
#   "прямой": 1,
#   "проходящей": 1,
#   "Введенскую": 1,
#   "Слободу": 1,
#   "речными": 1,
#   "теплоходами": 1,
#   "вертолётным": 1,
#   "транспортом": 1,
#   "Между": 1,
#   "Казанью": 1,
#   "Иннополисом": 1,
#   "курсирует": 1,
#   "регулярный": 1,
#   "автобус": 1,
#   "бесплатным": 1,
#   "стоимость": 3,
#   "проезда": 1,
#   "банковской": 1,
#   "картой": 1,
#   "125": 1,
#   "руб": 2,
#   "наличными": 1,
#   "150": 1,
#   "озвучивал": 1,
#   "платного": 1,
#   "моста": 1,
#   "сократит": 1,
#   "длительность": 1,
#   "поездки": 1,
#   "аэропорта": 2,
#   "15": 1,
#   "минут": 1,
#   "вместе": 1,
#   "Займищенским": 1,
#   "мостом": 1,
#   "станет": 1,
#   "окружной": 1,
#   "кольцевой": 1,
#   "2018": 3,
#   "действует": 2,
#   "беспилотное": 1,
#   "такси": 2,
#   "Яндекс": 2,
#   "тестовой": 1,
#   "пять": 1,
#   "точек": 1,
#   "посадки": 1,
#   "высадки": 1,
#   "пассажиров": 1,
#   "Они": 1,
#   "рядом": 1,
#   "ключевыми": 1,
#   "городскими": 1,
#   "объектами": 1,
#   "университетом": 5,
#   "стадионом": 1,
#   "медицинским": 1,
#   "жилым": 1,
#   "кварталом": 1,
#   "Зион": 1,
#   "деловым": 1,
#   "Беспилотный": 1,
#   "автомобиль": 1,
#   "ежедневно": 1,
#   "Воспользоваться": 1,
#   "могут": 1,
#   "все": 2,
#   "взрослые": 1,
#   "согласие": 1,
#   "тестировании": 1,
#   "испытаний": 1,
#   "беспилотных": 1,
#   "тестирование": 1,
#   "стартовало": 1,
#   "еще": 1,
#   "11": 2,
#   "регионах": 1,
#   "годах": 2,
#   "действовал": 1,
#   "автобусный": 1,
#   "маршрут": 1,
#   "обслуживаемый": 1,
#   "электробусом": 1,
#   "КАМАЗ": 1,
#   "2257": 1,
#   "создана": 2,
#   "РФ": 2,
#   "1131": 1,
#   "создании": 2,
#   "территориях": 1,
#   "Лаишевского": 2,
#   "муниципальных": 1,
#   "районов": 1,
#   "технико": 3,
#   "внедренческого": 2,
#   "типа": 2,
#   "стала": 1,
#   "пятой": 1,
#   "стране": 1,
#   "внедренческой": 1,
#   "зон": 1,
#   "Зеленоград": 1,
#   "Дубна": 1,
#   "Московской": 1,
#   "Санкт": 1,
#   "Петербург": 1,
#   "Томск": 1,
#   "второй": 1,
#   "Алабуга": 1,
#   "марте": 1,
#   "учредителями": 1,
#   "выступили": 1,
#   "Особые": 2,
#   "экономические": 2,
#   "получившее": 1,
#   "блокирующий": 1,
#   "пакет": 2,
#   "акция": 1,
#   "конце": 1,
#   "акций": 1,
#   "Площадка": 1,
#   "192": 1,
#   "71": 1,
#   "га": 3,
#   "расположенная": 1,
#   "1200": 2,
#   "предназначена": 1,
#   "размещения": 1,
#   "офисов": 1,
#   "лабораторий": 1,
#   "проведения": 1,
#   "научно": 2,
#   "исследовательских": 2,
#   "опытно": 2,
#   "конструкторских": 2,
#   "работ": 2,
#   "Вторая": 1,
#   "площадка": 1,
#   "производственная": 1,
#   "занимает": 1,
#   "101": 1,
#   "непосредственной": 2,
#   "близости": 2,
#   "международного": 2,
#   "Резиденты": 1,
#   "получают": 2,
#   "льготы": 1,
#   "налогу": 1,
#   "прибыль": 1,
#   "транспорт": 1,
#   "имущество": 1,
#   "землю": 1,
#   "страховые": 1,
#   "взносы": 1,
#   "доходы": 2,
#   "применении": 1,
#   "упрощенной": 1,
#   "системы": 2,
#   "налогообложения": 3,
#   "налогоплательщики": 1,
#   "сферы": 1,
#   "применяют": 1,
#   "упрощенную": 1,
#   "систему": 1,
#   "платят": 1,
#   "размере": 1,
#   "налог": 1,
#   "общего": 1,
#   "объема": 1,
#   "выборе": 1,
#   "объекта": 1,
#   "минус": 1,
#   "расходы": 1,
#   "Центр": 1,
#   "подбора": 1,
#   "персонала": 1,
#   "сотрудники": 1,
#   "безвозмездной": 1,
#   "основе": 2,
#   "помогают": 1,
#   "компаниям": 1,
#   "найти": 1,
#   "уровня": 1,
#   "middle": 1,
#   "senior": 1,
#   "собрать": 1,
#   "команду": 1,
#   "разработки": 1,
#   "привлечь": 1,
#   "кандидатов": 1,
#   "со": 2,
#   "всей": 1,
#   "ближнего": 1,
#   "зарубежья": 1,
#   "Сегодня": 1,
#   "работают": 1,
#   "133": 1,
#   "107": 1,
#   "партнеров": 3,
#   "Компании": 1,
#   "развивают": 1,
#   "свои": 1,
#   "проекты": 1,
#   "создав": 1,
#   "рабочих": 3,
#   "мест": 3,
#   "Среди": 1,
#   "Acronis": 1,
#   "Альфа": 1,
#   "Банк": 1,
#   "Атомдата": 1,
#   "госкорпорация": 1,
#   "Росатом": 1,
#   "Cognitive": 1,
#   "Technologies": 2,
#   "Schneider": 1,
#   "Electric": 1,
#   "Лаб": 1,
#   "Х5": 1,
#   "Технологии": 1,
#   "Открытая": 1,
#   "мобильная": 1,
#   "платформа": 1,
#   "Новые": 1,
#   "облачные": 1,
#   "технологии": 1,
#   "IVA": 1,
#   "ООО": 1,
#   "ИВКС": 1,
#   "группы": 1,
#   "ICL": 1,
#   "Сбербанк": 1,
#   "S7": 1,
#   "TechLab": 1,
#   "Тинькофф": 1,
#   "банк": 1,
#   "Пенсионный": 1,
#   "фонд": 1,
#   "декабрю": 1,
#   "резидентами": 1,
#   "партнерами": 1,
#   "проинвестировано": 1,
#   "млрд": 1,
#   "упрощенная": 1,
#   "процедура": 1,
#   "стартапа": 1,
#   "За": 1,
#   "начал": 1,
#   "работу": 1,
#   "61": 1,
#   "стартап": 1,
#   "Компаниям": 1,
#   "предоставляется": 1,
#   "специальных": 1,
#   "сервисов": 1,
#   "услуг": 1,
#   "бизнеса": 2,
#   "вошла": 1,
#   "мировой": 1,
#   "рейтинг": 1,
#   "Global": 1,
#   "Free": 1,
#   "Zones": 1,
#   "of": 1,
#   "the": 1,
#   "Year": 1,
#   "журнала": 1,
#   "fDi": 1,
#   "magazine": 1,
#   "входит": 1,
#   "Financial": 1,
#   "Times": 1,
#   "Ltd": 1,
#   "удостоена": 1,
#   "наград": 1,
#   "номинациях": 2,
#   "Специализации": 1,
#   "Индустрия": 1,
#   "0": 1,
#   "Инфраструктура": 1,
#   "Внедрение": 1,
#   "5G": 1,
#   "Гибкое": 1,
#   "офисное": 1,
#   "пространство": 1,
#   "получила": 1,
#   "награду": 1,
#   "номинации": 1,
#   "Социальная": 1,
#   "среда": 2,
#   "комплексном": 1,
#   "развитии": 1,
#   "уникальной": 1,
#   "экосистемы": 1,
#   "подписано": 1,
#   "соглашение": 1,
#   "первой": 1,
#   "бондовой": 1,
#   "трансграничной": 1,
#   "интернет": 1,
#   "торговли": 1,
#   "Пилотный": 1,
#   "созданию": 1,
#   "таможенного": 1,
#   "склада": 1,
#   "места": 1,
#   "почтового": 1,
#   "обмена": 1,
#   "реализован": 1,
#   "базе": 1,
#   "структурного": 1,
#   "подразделения": 1,
#   "Почты": 1,
#   "Компания": 1,
#   "выразила": 1,
#   "заинтересованность": 1,
#   "формировании": 1,
#   "бесшовных": 1,
#   "транспортных": 1,
#   "коридоров": 1,
#   "Российскую": 1,
#   "Федерацию": 1,
#   "внедрении": 1,
#   "цифровой": 1,
#   "платформы": 1,
#   "транспортного": 1,
#   "минимизирует": 1,
#   "издержки": 1,
#   "связанные": 1,
#   "временем": 1,
#   "прохождения": 1,
#   "административных": 1,
#   "процедур": 1,
#   "границе": 1,
#   "Технопарк": 1,
#   "Офисы": 1,
#   "исследовательские": 1,
#   "центры": 1,
#   "здании": 1,
#   "А": 1,
#   "чем": 1,
#   "рассматривают": 1,
#   "собственного": 1,
#   "производственные": 1,
#   "нужды": 1,
#   "лабораторию": 1,
#   "офисный": 1,
#   "др": 1,
#   "особые": 1,
#   "льготные": 1,
#   "условия": 1,
#   "аренде": 1,
#   "выкупу": 1,
#   "участков": 1,
#   "подключению": 1,
#   "инженерным": 1,
#   "сетям": 1,
#   "Ведется": 1,
#   "второго": 1,
#   "назван": 1,
#   "честь": 1,
#   "Николая": 1,
#   "Ивановича": 1,
#   "Лобачевского": 1,
#   "Площадь": 1,
#   "1500": 1,
#   "составит": 1,
#   "30": 1,
#   "Сдача": 1,
#   "эксплуатацию": 1,
#   "запланирована": 1,
#   "Образование": 1,
#   "наука": 1,
#   "расположенном": 1,
#   "частном": 1,
#   "Университете": 3,
#   "готовят": 1,
#   "управленцев": 1,
#   "проводят": 1,
#   "научные": 1,
#   "исследования": 1,
#   "робототехники": 1,
#   "учебном": 1,
#   "обучались": 1,
#   "300": 1,
#   "студентов": 4,
#   "313": 1,
#   "556": 1,
#   "обучает": 1,
#   "800": 1,
#   "бакалавров": 1,
#   "магистров": 1,
#   "аспирантов": 1,
#   "робототехнике": 1,
#   "Средний": 1,
#   "балл": 1,
#   "ЕГЭ": 1,
#   "среди": 1,
#   "поступающих": 1,
#   "95": 1,
#   "Обучение": 1,
#   "платное": 1,
#   "большая": 1,
#   "грант": 1,
#   "покрывающий": 1,
#   "обучения": 1,
#   "заключил": 1,
#   "соглашения": 1,
#   "подготовке": 1,
#   "проведении": 1,
#   "Министерства": 2,
#   "обороны": 1,
#   "Энвижн": 1,
#   "Груп": 1,
#   "Mail": 1,
#   "Ru": 1,
#   "Group": 1,
#   "концерна": 1,
#   "Радиотехнические": 1,
#   "Информационные": 1,
#   "Строительство": 1,
#   "четырёх": 1,
#   "корпусов": 1,
#   "общежитий": 1,
#   "35": 1,
#   "профинансировано": 1,
#   "бюджета": 1,
#   "государство": 1,
#   "внесло": 1,
#   "уставной": 1,
#   "капитал": 1,
#   "миллиарда": 1,
#   "сотрудничает": 1,
#   "Университетом": 3,
#   "Карнеги": 1,
#   "Меллон": 1,
#   "Швейцарской": 1,
#   "высшей": 1,
#   "технической": 1,
#   "школой": 2,
#   "Цюриха": 1,
#   "Национальным": 1,
#   "Амстердама": 1,
#   "Корейским": 1,
#   "институтом": 2,
#   "передовых": 1,
#   "Московским": 2,
#   "физико": 1,
#   "техническим": 2,
#   "государственным": 1,
#   "Высшей": 1,
#   "экономики": 1,
#   "ИТМО": 1,
#   "Казанским": 2,
#   "национальным": 1,
#   "исследовательским": 1,
#   "другими": 1,
#   "российскими": 1,
#   "зарубежными": 1,
#   "вузами": 1,
#   "Довузовское": 1,
#   "образованиеС": 1,
#   "сентября": 1,
#   "международная": 1,
#   "образовательными": 1,
#   "программами": 1,
#   "английском": 2,
#   "русском": 1,
#   "татарском": 1,
#   "языках": 1,
#   "общеобразовательная": 1,
#   "январе": 1,
#   "университете": 1,
#   "открылся": 1,
#   "интернат": 1,
#   "одарённых": 1,
#   "детей": 1,
#   "ориентированный": 1,
#   "преподавание": 2,
#   "Учебная": 1,
#   "программа": 1,
#   "лицея": 1,
#   "рассчитана": 1,
#   "учащихся": 1,
#   "классов": 1,
#   "языке": 1,
#   "предоставляет": 1,
#   "старшеклассникам": 1,
#   "выбор": 1,
#   "курсов": 1,
#   "факультативных": 1,
#   "занятий": 1,
#   "образовательном": 1,
#   "процессе": 1,
#   "Здравоохранение": 1,
#   "рассчитанный": 1,
#   "500": 2,
#   "посещений": 1,
#   "смену": 1,
#   "Инвестиции": 1,
#   "клиники": 1,
#   "составили": 1,
#   "326": 1,
#   "миллионов": 2,
#   "предоставленных": 1,
#   "составило": 1,
#   "десятков": 1,
#   "обеспечения": 1,
#   "загрузки": 1,
#   "учреждения": 1,
#   "открыта": 1,
#   "Консультационная": 1,
#   "поликлиника": 1,
#   "РКБ": 1,
#   "принимает": 1,
#   "пациентов": 2,
#   "медицинском": 1,
#   "центре": 1,
#   "клинической": 1,
#   "больнице": 1,
#   "стартовал": 1,
#   "реабилитации": 1,
#   "перенесших": 1,
#   "коронавирусную": 1,
#   "инфекцию": 1,
#   "программы": 1,
#   "госгарантий": 1,
#   "полису": 1,
#   "ОМС": 1,
#   "Специализированное": 1,
#   "лечение": 1,
#   "подразумевает": 1,
#   "консультации": 1,
#   "лечебную": 1,
#   "физкультуру": 1,
#   "дыхательную": 1,
#   "гимнастику": 1,
#   "лечебный": 1,
#   "массаж": 1,
#   "современные": 1,
#   "методы": 1,
#   "физиотерапии": 1,
#   "Культура": 1,
#   "спорт": 1,
#   "имеется": 2,
#   "бассейном": 1,
#   "специализированными": 1,
#   "залами": 1,
#   "стадион": 1,
#   "футбольным": 1,
#   "полем": 1,
#   "беговыми": 1,
#   "дорожками": 1,
#   "баскетбольной": 1,
#   "площадкой": 1,
#   "катком": 1,
#   "детскими": 1,
#   "игровыми": 1,
#   "зонами": 1,
#   "Рекреационная": 1,
#   "представлена": 1,
#   "расположенными": 1,
#   "клубом": 1,
#   "горнолыжным": 1,
#   "спортивно": 1,
#   "оздоровительным": 1,
#   "комплексом": 1,
#   "стрельбищем": 1,
#   "объектом": 1,
#   "XXVII": 1,
#   "Всемирной": 1,
#   "летней": 1,
#   "Универсиады": 1,
#   "Планы": 1,
#   "лето": 1,
#   "включали": 1,
#   "открытие": 1,
#   "двух": 1,
#   "парков": 1,
#   "один": 1,
#   "должен": 1,
#   "расположиться": 1,
#   "берегу": 1,
#   "реки": 1,
#   "метрах": 1,
#   "музея": 1,
#   "заповедника": 1,
#   "Остров": 1,
#   "град": 1,
#   "Примечания": 1,
#   "Документы": 1,
#   "Материалы": 1,
#   "обоснованию": 1,
#   "генерального": 1,
#   "Генеральный": 2,
#   "Татинвестгражданпроект": 2,
#   "Охрана": 1,
#   "окружающей": 1,
#   "среды": 1,
#   "Источники": 1,
#   "Ссылки": 1,
#   "innopolis": 1,
#   "ru": 1,
#   "официальный": 1,
#   "сайт": 1
# }

# %% [markdown]
# ## Task 2
#
# Write a python program that does the following :
# 1. Retrieve data from sklearn --> (from sklearn.datasets import fetch_20newsgroups)
# 2. Preprocess the data
# 3. Do classification using any classical machine learning method

# %%
from sklearn.datasets import fetch_20newsgroups

dataset = fetch_20newsgroups()

# %%
# Remove extra spaces, quotes and e-mails
for key, _ in enumerate(dataset.data):
    dataset.data[key].replace(r"(From :\S*@\S*\s?) | (\') | (\")", "")
    dataset.data[key].replace(r"\s+", " ")

# %%
# Reference: https://blog.cambridgespark.com/tutorial-an-introduction-to-text-classification-d36769c593ba

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_validate
from sklearn.metrics import f1_score, accuracy_score, recall_score, precision_score, make_scorer

vectorizer = TfidfVectorizer(stop_words="english", min_df=3)
X, y = dataset.data, dataset.target

lr_pipeline = Pipeline([
    ('TF/IDF Vectorizer', vectorizer),
    ('Multinomial Logistic Regression', LogisticRegression(class_weight="balanced",solver="lbfgs", multi_class="multinomial", max_iter=1000))
])


accuracy, precision, recall, f1 = make_scorer(accuracy_score), \
                                  make_scorer(precision_score, average="macro"), make_scorer(recall_score, average="macro"), make_scorer(f1_score, average="macro")
scoring = {
    'accuracy': accuracy,
    'precision': precision,
    'recall': recall,
    'f1': f1
}                                  
cross_validate(lr_pipeline, X, y, scoring=scoring)
# Out:
# {'fit_time': array([20.26185131, 19.30852914, 20.51253009, 19.19468284, 21.57319403]),
#  'score_time': array([1.06772637, 1.11374068, 1.1017158 , 0.9401474 , 0.97732687]),
#  'test_accuracy': array([0.89703933, 0.90057446, 0.89527176, 0.90278392, 0.9071618 ]),
#  'test_precision': array([0.90079286, 0.90239564, 0.89663541, 0.90323813, 0.91120564]),
#  'test_recall': array([0.89499542, 0.89895654, 0.89369611, 0.90027396, 0.90567413]),
#  'test_f1': array([0.89697356, 0.90020187, 0.89461968, 0.90138168, 0.90750561])}

# %% [markdown]
# ## Task 3
#
# Write a python program that does the following :
# 1. Preprocess the given data
# 2. Find entities in the data using regular expressions: dates, names, locations
# 3. Anonymise the names of US presidents
# 4. Highlight the locations
# 5. Sort by dates

# %%
TEXT = [
    "Barack Obama was the 44th president of the US and he followed George W. Bush and was followed by Donald Trump in 2017",
    "As a young man, George H.W. Bush served in World War II as a fighter pilot. In 1944, he was shot down and had to parachute to safety.",
    "Before he was president, George W. Bush was a cheerleader, a fraternity brother, an oilman, an owner of a professional baseball team, and a governor. After leaving office in 2009, Bush learned to paint.",
    "Here's something else you probably didn't know about John Adams: He died on the Fourth of July. And he wasn't the only commander in chief to do so. In fact, three of the nation's five founding fathers—Adams, Thomas Jefferson, and James Monroe—died on Independence Day. Adams and Jefferson even passed on the same exact day: July 4, 1826, which happened to be the 50th anniversary of the adoption of the Declaration of Independence.",
    "At 6 feet 4 inches tall, Abraham Lincoln and Lyndon B. Johnson were America's tallest presidents. But what about America's shortest president? That distinction goes to founding father James Madison (1809-1817), who, at 5 feet 4 inches tall, was a full foot shorter than his tallest peers.",
    "That changed, however, in October 1860, when Lincoln received a letter from an 11-year-old girl named Grace Bedell. 'If you will let your whiskers grow I will try and get [my brothers] to vote for you,' Bedell wrote to Lincoln. 'You would look a great deal better for your face is so thin. All the ladies like whiskers and they would tease their husbands to vote for you and then you would be president.'",
    "Richard Nixon was hardly the first president who liked to unwind by rolling a few strikes. Harry S. Truman also enjoyed bowling, and opened the first White House bowling alley in 1947. ",
    "If you had to bet on which U.S. president was the biggest movie fan, you'd probably put your money on America's actor-turned-president, Ronald Reagan (1981-1989). And that would be a great guess. Reagan reportedly watched 363 movies during his two terms in office.",
    "Thomas Jefferson offered to sell his personal library when the Library of Congress was burned by the British during the War of 1812. He sold them 6487 books from his own collection, the largest in America at the time.",
    "Born in New York in 1782, Martin Van Buren was the first president to have been born after the American Revolution, technically making him the first American-born president.",
    "Benjamin Harrison had a tight-knit family and loved to amuse and dote on his grandchildren. He put up the first recorded White House Christmas tree in 1889, and was known to put on the Santa suit for entertainment.",
    "A 16-year-old Bill Clinton managed to shake hands with President John F. Kennedy at a Boys Nation event in 1963. This would take place just four months before Kennedy's assassination.",
    "In 1993—two years before he became the governor of Texas—George W. Bush ran the Houston marathon, finishing with a time of 3:44:52. He is the only president to have ever run a marathon.",
]

# %%
# %pip install datefinder
# Out:
# Requirement already satisfied: datefinder in c:\users\aleksandr\anaconda3\envs\mlenv\lib\site-packages (0.7.3)
# Requirement already satisfied: regex>=2017.02.08 in c:\users\aleksandr\anaconda3\envs\mlenv\lib\site-packages (from datefinder) (2022.10.31)
# Requirement already satisfied: python-dateutil>=2.4.2 in c:\users\aleksandr\anaconda3\envs\mlenv\lib\site-packages (from datefinder) (2.8.2)
# Requirement already satisfied: pytz in c:\users\aleksandr\anaconda3\envs\mlenv\lib\site-packages (from datefinder) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\aleksandr\anaconda3\envs\mlenv\lib\site-packages (from python-dateutil>=2.4.2->datefinder) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
presidents = requests.get("https://gist.githubusercontent.com/namuol/2657233/raw/74135b2637e624848c163759be9cd14ae33f5153/presidents.csv").text
presidents = presidents.split('\n')[1:]
presidents = [y.split(',')[1] for y in presidents]
presidents
presidents += ["Donald Trump", "Joe Biden"]

# %%
from datefinder import find_dates

# %%
# %pip install geotext
# Out:
# Requirement already satisfied: geotext in c:\users\aleksandr\anaconda3\envs\mlenv\lib\site-packages (0.4.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from geotext import GeoText
def find_locations(text):
    geotext = GeoText(text)
    return geotext.cities

# %%
# Reference: https://stackoverflow.com/questions/20290870/improving-the-extraction-of-human-names-with-nltk

import nltk

name = r"[A-Z][A-Za-z]+\s[A-Z](?:\.\s[A-Z][A-Za-z]+|[A-Za-z]+)"


def get_human_names(text):
    person_list = []
    tokens = nltk.tokenize.word_tokenize(text)
    pos = nltk.pos_tag(tokens)
    sentt = nltk.ne_chunk(pos, binary = False)

    person = []
    name = ""
    for subtree in sentt.subtrees(filter=lambda t: t.label() == 'PERSON'):
        for leaf in subtree.leaves():
            person.append(leaf[0])
        for part in person:
                name += part + ' '
        if name[:-1] not in person_list:
                person_list.append(name[:-1])
        name = ''
        person = []
    return person_list

def in_extracted(name_, extracted_names):
    parts = name_.split(' ')
    first, last = parts[0], parts[-1]
    return first in extracted_names or last in extracted_names or name_ in extracted_names

def process(text: str):
    names = re.findall(name, text)
    extracted_names = get_human_names(text)
    i = 1
    anonymizer = {}

    for name_ in set.intersection(set(presidents), set(names)):
    # for name_ in presidents:
        anonymizer[name_] = i
        i += 1
    print(anonymizer)
    for extracted_name in extracted_names:
        for name_, i in list(anonymizer.items()):
            if extracted_name in name_.split(" ") or extracted_name == name:
                anonymizer[extracted_name] = i


    output = "" + text
    for name_, i in anonymizer.items():
        output = output.replace(name_, f"X{i}")
    locations = find_locations(text)
    for location in locations:
        output = output.replace(location, f"**{location}**")
    dates = list(find_dates(text))
    
    return output, extracted_names, dates, locations

for sentence in TEXT:
    modified_text, names, dates, locations = process(sentence)
    dates = [date.strftime("%Y-%m-%d") for date in dates]
    print(sentence)
    print(modified_text)
    print(f"Names: {names}")
    print(f"Dates: {dates}")
    print(f"Locations: {locations}")
# Out:
# {'Barack Obama': 1, 'George W. Bush': 2, 'Donald Trump': 3}
# Barack Obama was the 44th president of the US and he followed George W. Bush and was followed by Donald Trump in 2017
# X1 was the 44th president of the US and he followed X2 and was followed by X3 in 2017
# Names: ['Barack', 'Obama', 'George W. Bush', 'Donald Trump']
# Dates: ['2044-01-30', '2023-02-01']
# Locations: ['George']
# {}
# As a young man, George H.W. Bush served in World War II as a fighter pilot. In 1944, he was shot down and had to parachute to safety.
# As a young man, **George** H.W. Bush served in World War II as a fighter pilot. In 1944, he was shot down and had to parachute to safety.
# Names: ['George', 'Bush']
# Dates: ['1944-01-30']
# Locations: ['George']
# {'George W. Bush': 1}
# Before he was president, George W. Bush was a cheerleader, a fraternity brother, an oilman, an owner of a professional baseball team, and a governor. After leaving office in 2009, Bush learned to paint.
# Before he was president, X1 was a cheerleader, a fraternity brother, an oilman, an owner of a professional baseball team, and a governor. After leaving office in 2009, X1 learned to paint.
# Names: ['George W. Bush', 'Bush']
# Dates: ['2009-01-30']
# Locations: ['George']
# {'Thomas Jefferson': 1, 'John Adams': 2, 'James Monroe': 3}
# Here's something else you probably didn't know about John Adams: He died on the Fourth of July. And he wasn't the only commander in chief to do so. In fact, three of the nation's five founding fathers—Adams, Thomas Jefferson, and James Monroe—died on Independence Day. Adams and Jefferson even passed on the same exact day: July 4, 1826, which happened to be the 50th anniversary of the adoption of the Declaration of Independence.
# Here's something else you probably didn't know about X2: He died on the Fourth of July. And he wasn't the only commander in chief to do so. In fact, three of the nation's five founding fathers—X2, X1, and X3—died on **Independence** Day. X2 and X1 even passed on the same exact day: July 4, 1826, which happened to be the 50th anniversary of the adoption of the Declaration of **Independence**.
# Names: ['John Adams', 'Thomas Jefferson', 'James', 'Adams', 'Jefferson']
# Dates: ['2050-01-30']
# Locations: ['Jefferson', 'Independence']
# {'Abraham Lincoln': 1, 'Lyndon B. Johnson': 2, 'James Madison': 3}
# At 6 feet 4 inches tall, Abraham Lincoln and Lyndon B. Johnson were America's tallest presidents. But what about America's shortest president? That distinction goes to founding father James Madison (1809-1817), who, at 5 feet 4 inches tall, was a full foot shorter than his tallest peers.
# At 6 feet 4 inches tall, X1 and X2 were America's tallest presidents. But what about America's shortest president? That distinction goes to founding father X3 (1809-1817), who, at 5 feet 4 inches tall, was a full foot shorter than his tallest peers.
# Names: ['Abraham Lincoln', 'Lyndon B. Johnson', 'James Madison']
# Dates: ['2023-01-06', '2023-01-04', '2023-01-05', '2023-01-04']
# Locations: ['Johnson']
# {}
# That changed, however, in October 1860, when Lincoln received a letter from an 11-year-old girl named Grace Bedell. 'If you will let your whiskers grow I will try and get [my brothers] to vote for you,' Bedell wrote to Lincoln. 'You would look a great deal better for your face is so thin. All the ladies like whiskers and they would tease their husbands to vote for you and then you would be president.'
# That changed, however, in October 1860, when ****Lincoln**** received a letter from an 11-year-old girl named Grace Bedell. 'If you will let your whiskers grow I will try and get [my brothers] to vote for you,' Bedell wrote to ****Lincoln****. 'You would look a great deal better for your face is so thin. All the ladies like whiskers and they would tease their husbands to vote for you and then you would be president.'
# Names: ['Lincoln', 'Grace Bedell', 'Bedell']
# Dates: ['1860-10-30', '2023-01-11']
# Locations: ['Lincoln', 'Lincoln']
# {'Harry S. Truman': 1, 'Richard Nixon': 2}
# Richard Nixon was hardly the first president who liked to unwind by rolling a few strikes. Harry S. Truman also enjoyed bowling, and opened the first White House bowling alley in 1947.
# X2 was hardly the first president who liked to unwind by rolling a few strikes. X1 also enjoyed bowling, and opened the first White House bowling alley in 1947.
# Names: ['Richard', 'Nixon', 'Harry S. Truman']
# Dates: ['1947-01-30']
# Locations: []
# {'Ronald Reagan': 1}
# If you had to bet on which U.S. president was the biggest movie fan, you'd probably put your money on America's actor-turned-president, Ronald Reagan (1981-1989). And that would be a great guess. Reagan reportedly watched 363 movies during his two terms in office.
# If you had to bet on which U.S. president was the biggest movie fan, you'd probably put your money on America's actor-turned-president, X1 (1981-1989). And that would be a great guess. X1 reportedly watched 363 movies during his two terms in office.
# Names: ['Ronald Reagan', 'Reagan']
# Dates: ['0363-01-30']
# Locations: []
# {'Thomas Jefferson': 1}
# Thomas Jefferson offered to sell his personal library when the Library of Congress was burned by the British during the War of 1812. He sold them 6487 books from his own collection, the largest in America at the time.
# X1 offered to sell his personal library when the Library of Congress was burned by the British during the War of 1812. He sold them 6487 books from his own collection, the largest in America at the time.
# Names: ['Thomas', 'Jefferson']
# Dates: ['1812-01-30', '6487-01-30']
# Locations: []
# {}
# Born in New York in 1782, Martin Van Buren was the first president to have been born after the American Revolution, technically making him the first American-born president.
# **Born** in **New York** in 1782, Martin Van Buren was the first president to have been born after the American Revolution, technically making him the first American-born president.
# Names: ['Martin Van Buren']
# Dates: ['1782-03-30']
# Locations: ['Born', 'New York']
# {'Benjamin Harrison': 1}
# Benjamin Harrison had a tight-knit family and loved to amuse and dote on his grandchildren. He put up the first recorded White House Christmas tree in 1889, and was known to put on the Santa suit for entertainment.
# X1 had a tight-knit family and loved to amuse and dote on his grandchildren. He put up the first recorded White House Christmas tree in 1889, and was known to put on the Santa suit for entertainment.
# Names: ['Benjamin', 'Harrison']
# Dates: ['1889-01-30']
# Locations: []
# {'Bill Clinton': 1}
# A 16-year-old Bill Clinton managed to shake hands with President John F. Kennedy at a Boys Nation event in 1963. This would take place just four months before Kennedy's assassination.
# A 16-year-old X1 managed to shake hands with President John F. Kennedy at a Boys Nation event in 1963. This would take place just four months before Kennedy's assassination.
# Names: ['Bill Clinton', 'John F. Kennedy', 'Kennedy']
# Dates: ['2023-01-16', '1963-01-30']
# Locations: []
# {'George W. Bush': 1}
# In 1993—two years before he became the governor of Texas—George W. Bush ran the Houston marathon, finishing with a time of 3:44:52. He is the only president to have ever run a marathon.
# In 1993—two years before he became the governor of **Texas**—X1 ran the **Houston** marathon, finishing with a time of 3:44:52. He is the only president to have ever run a marathon.
# Names: ['Bush']
# Dates: ['2023-01-30']
# Locations: ['Texas', 'George', 'Houston']

# %%
LOCATIONS = [...]
NAMES = [...]

# %% [markdown]
# ## Task 4
#
# Write a python program that does the following :
# 1. Preprocess the data from Task 3
# 2. Find entities in the data using [Gazetteers](https://gatenlp.readthedocs.io/en/latest/gazetteers/) from gatenlp: dates, names, locations
# 3. Anonymise the names of US presidents
# 4. Highlight the locations
# 5. Sort by dates
